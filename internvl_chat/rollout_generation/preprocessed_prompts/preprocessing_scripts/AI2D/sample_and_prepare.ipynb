# %%
import json
import random
import uuid
import os
import shutil
from pathlib import Path
import pandas as pd
from collections import defaultdict

print("Imports completed successfully")
# Out:
# Imports completed successfully

# %%
# Load the full JSONL file
input_file = "full_ai2d_train_12k_en_20240410_extracted.jsonl"
data = []

print(f"Loading data from {input_file}...")
with open(input_file, 'r') as f:
    for line in f:
        data.append(json.loads(line.strip()))

print(f"Loaded {len(data)} records")
print("Sample record:", data[0])
# Out:
# Loading data from full_ai2d_train_12k_en_20240410_extracted.jsonl...
# Loaded 12413 records
# Sample record: {'image': 'MMPR-v1.2-prompts/correctness_images/ai2d_train_12k_en_20240410_extracted/images/4781.png', 'question': 'How many flowers are shown?\n1\n3\n2\n4\nPlease answer the question based on the options mentioned before.', 'answer': '2'}

# %%
# Group by unique images to ensure no duplicates
unique_images = {}
for record in data:
    image_path = record["image"]
    if image_path not in unique_images:
        unique_images[image_path] = record

print(f"Found {len(unique_images)} unique images")
# Out:
# Found 3976 unique images

# %%
# Group by unique images to ensure no duplicates
unique_questions = {}
for record in data:
    question = record["question"]
    if question not in unique_questions:
        unique_questions[question] = record

print(f"Found {len(unique_questions)} unique questions")
# Out:
# Found 12409 unique questions

# %%
# Sample 15K unique records
sample_size = 12000
unique_records = list(unique_questions.values())

if len(unique_records) < sample_size:
    print(f"Warning: Only {len(unique_records)} unique images available, less than requested {sample_size}")
    sampled_data = unique_records
else:
    # Use random.sample for sampling without replacement
    random.seed(42)  # For reproducibility
    sampled_data = random.sample(unique_records, sample_size)

print(f"Selected {len(sampled_data)} records for subset")
# Out:
# Selected 12000 records for subset

# %%
# Add UUID to each record and save subset
subset_output_file = "ai2d_open_ans_12K_v1_subset.jsonl"

print("Adding UIDs and saving subset...")
with open(subset_output_file, 'w') as f:
    for record in sampled_data:
        # Add UID to the record
        record_with_uid = record.copy()
        record_with_uid["uid"] = str(uuid.uuid4())
        
        # Write to file
        f.write(json.dumps(record_with_uid) + "\n")

print(f"Saved {len(sampled_data)} records to {subset_output_file}")
print("Sample record with UID:", json.loads(open(subset_output_file).readline()))
# Out:
# Adding UIDs and saving subset...
# Saved 12000 records to ai2d_open_ans_12K_v1_subset.jsonl
# Sample record with UID: {'image': 'MMPR-v1.2-prompts/correctness_images/ai2d_train_12k_en_20240410_extracted/images/4561.png', 'question': 'What object is shown in the diagram above?\nOrange tree\nMint Plant\nNone of the above\nApple Tree\nPlease answer the question based on the options mentioned before.', 'answer': 'Mint Plant', 'uid': 'be7ce904-2513-4655-9653-d147db2280c7'}

# %%
source_image_dir = "/data/users/brandon/ob1-projects/MMPR-v1.2-prompts"
loaded_image_path = "MMPR-v1.2-prompts/correctness_images/ai2d_train_12k_en_20240410_extracted/images/4561.png"

source_image_path = "/".join(loaded_image_path.split("/")[1::])
full_source_image_path = os.path.join(source_image_dir, source_image_path)

print("full_source_image_path: ", full_source_image_path)
# print("loaded_image_path: ", loaded_image_path)


image_filename = os.path.basename(loaded_image_path)
print("image_filename: ", image_filename)
# Out:
# full_source_image_path:  /data/users/brandon/ob1-projects/MMPR-v1.2-prompts/correctness_images/ai2d_train_12k_en_20240410_extracted/images/4561.png
# image_filename:  4561.png

# %%
import os
import json
import shutil

# Copy images to subset_images directory
subset_output_file = "ai2d_open_ans_12K_v1_subset.jsonl"
subset_images_dir = "subset_images"
os.makedirs(subset_images_dir, exist_ok=True)

print(f"Copying images to {subset_images_dir} directory...")

# Read the subset file to get the image paths
copied_count = 0
failed_count = 0

with open(subset_output_file, 'r') as f:
    for line in f:
        record = json.loads(line.strip())
        source_image_path = "/".join(record["image"].split("/")[1::])

        source_image_dir = "/data/users/brandon/ob1-projects/MMPR-v1.2-prompts"

        full_source_image_path = os.path.join(source_image_dir, source_image_path)

        image_filename = os.path.basename(source_image_path)
        
        dest_image_path = os.path.join(subset_images_dir, image_filename)
        
        # Skip if destination already exists to avoid overwriting
        if os.path.exists(dest_image_path):
            print(f"Skipping {image_filename} - already exists")
            copied_count += 1
            continue
        
        try:
            if os.path.exists(full_source_image_path):
                shutil.copy2(full_source_image_path, dest_image_path)
                copied_count += 1
                if copied_count % 1000 == 0:  # Progress update every 1000 files
                    print(f"Copied {copied_count} images so far...")
            else:
                print(f"Warning: Source image not found: {full_source_image_path}")
                failed_count += 1
        except Exception as e:
            print(f"Error copying {full_source_image_path}: {e}")
            failed_count += 1

print(f"Successfully copied {copied_count} images")
print(f"Failed to copy {failed_count} images")
# Out:
# Copying images to subset_images directory...
# Skipping 2098.png - already exists
# Skipping 136.png - already exists
# Skipping 1277.png - already exists
# Skipping 493.png - already exists
# Skipping 2585.png - already exists
# Skipping 1986.png - already exists
# Skipping 1775.png - already exists
# Skipping 2248.png - already exists
# Skipping 1769.png - already exists
# Skipping 1295.png - already exists
# Skipping 1776.png - already exists
# Skipping 4845.png - already exists
# Skipping 1989.png - already exists
# Skipping 809.png - already exists
# Skipping 494.png - already exists
# Skipping 799.png - already exists
# Skipping 929.png - already exists
# Skipping 482.png - already exists
# Skipping 1769.png - already exists
# Skipping 907.png - already exists
# Skipping 515.png - already exists
# Skipping 416.png - already exists
# Skipping 1801.png - already exists
# Skipping 488.png - already exists
# Skipping 244.png - already exists
# Skipping 1043.png - already exists
# Skipping 1949.png - already exists
# Skipping 1760.png - already exists
# Skipping 536.png - already exists
# Skipping 26.png - already exists
# Skipping 904.png - already exists
# Skipping 1274.png - already exists
# Skipping 1933.png - already exists
# Skipping 1986.png - already exists
# Skipping 488.png - already exists
# Skipping 1787.png - already exists
# Skipping 3770.png - already exists
# Skipping 511.png - already exists
# Skipping 2042.png - already exists
# Skipping 2117.png - already exists
# Skipping 1995.png - already exists
# Skipping 1859.png - already exists
# Skipping 3938.png - already exists
# Skipping 383.png - already exists
# Skipping 310.png - already exists
# Skipping 2058.png - already exists
# Skipping 318.png - already exists
# Skipping 4756.png - already exists
# Skipping 2736.png - already exists
# Skipping 2147.png - already exists
# Skipping 278.png - already exists
# Skipping 806.png - already exists
# Skipping 2058.png - already exists
# Skipping 2078.png - already exists
# Skipping 2003.png - already exists
# Skipping 1914.png - already exists
# Skipping 250.png - already exists
# Skipping 2050.png - already exists
# Skipping 268.png - already exists
# Skipping 244.png - already exists
# Skipping 3938.png - already exists
# Skipping 136.png - already exists
# Skipping 2585.png - already exists
# Skipping 3782.png - already exists
# Skipping 2308.png - already exists
# Skipping 2593.png - already exists
# Skipping 568.png - already exists
# Skipping 1883.png - already exists
# Skipping 799.png - already exists
# Skipping 2200.png - already exists
# Skipping 1973.png - already exists
# Skipping 1995.png - already exists
# Skipping 2624.png - already exists
# Skipping 148.png - already exists
# Skipping 266.png - already exists
# Skipping 245.png - already exists
# Skipping 171.png - already exists
# Skipping 765.png - already exists
# Skipping 873.png - already exists
# Skipping 385.png - already exists
# Skipping 312.png - already exists
# Skipping 48.png - already exists
# Skipping 1829.png - already exists
# Skipping 910.png - already exists
# Skipping 1853.png - already exists
# Skipping 3539.png - already exists
# Skipping 2651.png - already exists
# Skipping 405.png - already exists
# Skipping 1863.png - already exists
# Skipping 4637.png - already exists
# Skipping 198.png - already exists
# Skipping 1979.png - already exists
# Skipping 29.png - already exists
# Skipping 17.png - already exists
# Skipping 2538.png - already exists
# Skipping 827.png - already exists
# Skipping 158.png - already exists
# Skipping 26.png - already exists
# Skipping 1787.png - already exists
# Skipping 493.png - already exists
# Skipping 1324.png - already exists
# Skipping 1768.png - already exists
# Skipping 2618.png - already exists
# Skipping 37.png - already exists
# Skipping 17.png - already exists
# Skipping 880.png - already exists
# Skipping 2308.png - already exists
# Skipping 21.png - already exists
# Skipping 2097.png - already exists
# Skipping 140.png - already exists
# Skipping 2103.png - already exists
# Skipping 2058.png - already exists
# Skipping 1933.png - already exists
# Skipping 1986.png - already exists
# Skipping 30.png - already exists
# Skipping 493.png - already exists
# Skipping 2096.png - already exists
# Skipping 2172.png - already exists
# Skipping 1893.png - already exists
# Skipping 2398.png - already exists
# Skipping 2671.png - already exists
# Skipping 953.png - already exists
# Skipping 278.png - already exists
# Skipping 25.png - already exists
# Skipping 2924.png - already exists
# Skipping 1768.png - already exists
# Skipping 2221.png - already exists
# Skipping 2022.png - already exists
# Skipping 2190.png - already exists
# Skipping 1910.png - already exists
# Skipping 1801.png - already exists
# Skipping 312.png - already exists
# Skipping 4321.png - already exists
# Skipping 23.png - already exists
# Skipping 822.png - already exists
# Skipping 4132.png - already exists
# Skipping 2121.png - already exists
# Skipping 821.png - already exists
# Skipping 2127.png - already exists
# Skipping 47.png - already exists
# Skipping 1974.png - already exists
# Skipping 4442.png - already exists
# Skipping 1962.png - already exists
# Skipping 492.png - already exists
# Skipping 2869.png - already exists
# Skipping 1494.png - already exists
# Skipping 1807.png - already exists
# Skipping 2652.png - already exists
# Skipping 267.png - already exists
# Skipping 1988.png - already exists
# Skipping 14.png - already exists
# Skipping 2377.png - already exists
# Skipping 4158.png - already exists
# Skipping 2012.png - already exists
# Skipping 300.png - already exists
# Skipping 875.png - already exists
# Skipping 2012.png - already exists
# Skipping 1761.png - already exists
# Skipping 1310.png - already exists
# Skipping 236.png - already exists
# Skipping 2371.png - already exists
# Skipping 2082.png - already exists
# Skipping 1960.png - already exists
# Skipping 444.png - already exists
# Skipping 2531.png - already exists
# Skipping 2070.png - already exists
# Skipping 194.png - already exists
# Skipping 901.png - already exists
# Skipping 368.png - already exists
# Skipping 517.png - already exists
# Skipping 1933.png - already exists
# Skipping 3785.png - already exists
# Skipping 2064.png - already exists
# Skipping 2696.png - already exists
# Skipping 806.png - already exists
# Skipping 2004.png - already exists
# Skipping 2078.png - already exists
# Skipping 258.png - already exists
# Skipping 707.png - already exists
# Skipping 440.png - already exists
# Skipping 198.png - already exists
# Skipping 2173.png - already exists
# Skipping 1884.png - already exists
# Skipping 267.png - already exists
# Skipping 1801.png - already exists
# Skipping 2104.png - already exists
# Skipping 338.png - already exists
# Skipping 4372.png - already exists
# Skipping 1975.png - already exists
# Skipping 1878.png - already exists
# Skipping 1999.png - already exists
# Skipping 785.png - already exists
# Skipping 2305.png - already exists
# Skipping 202.png - already exists
# Copied 1000 images so far...
# Skipping 431.png - already exists
# Skipping 1981.png - already exists
# Skipping 518.png - already exists
# Skipping 2585.png - already exists
# Skipping 2067.png - already exists
# Skipping 2528.png - already exists
# Skipping 1961.png - already exists
# Skipping 338.png - already exists
# Skipping 86.png - already exists
# Skipping 1907.png - already exists
# Skipping 2283.png - already exists
# Skipping 2056.png - already exists
# Skipping 125.png - already exists
# Skipping 1656.png - already exists
# Skipping 485.png - already exists
# Skipping 298.png - already exists
# Skipping 4840.png - already exists
# Skipping 244.png - already exists
# Skipping 444.png - already exists
# Skipping 1832.png - already exists
# Skipping 782.png - already exists
# Skipping 48.png - already exists
# Skipping 250.png - already exists
# Skipping 1784.png - already exists
# Skipping 2172.png - already exists
# Skipping 4105.png - already exists
# Skipping 17.png - already exists
# Skipping 2731.png - already exists
# Skipping 4161.png - already exists
# Skipping 1765.png - already exists
# Skipping 25.png - already exists
# Skipping 166.png - already exists
# Skipping 2618.png - already exists
# Skipping 439.png - already exists
# Skipping 822.png - already exists
# Skipping 897.png - already exists
# Skipping 3981.png - already exists
# Skipping 29.png - already exists
# Skipping 258.png - already exists
# Skipping 47.png - already exists
# Skipping 3029.png - already exists
# Skipping 1889.png - already exists
# Skipping 428.png - already exists
# Skipping 1767.png - already exists
# Skipping 449.png - already exists
# Skipping 101.png - already exists
# Skipping 2071.png - already exists
# Skipping 1253.png - already exists
# Skipping 1961.png - already exists
# Skipping 2612.png - already exists
# Skipping 800.png - already exists
# Skipping 2182.png - already exists
# Skipping 2696.png - already exists
# Skipping 800.png - already exists
# Skipping 244.png - already exists
# Skipping 2685.png - already exists
# Skipping 861.png - already exists
# Skipping 1210.png - already exists
# Skipping 241.png - already exists
# Skipping 2103.png - already exists
# Skipping 1855.png - already exists
# Skipping 531.png - already exists
# Skipping 439.png - already exists
# Skipping 2071.png - already exists
# Skipping 194.png - already exists
# Skipping 1858.png - already exists
# Skipping 4269.png - already exists
# Skipping 2110.png - already exists
# Skipping 444.png - already exists
# Skipping 1830.png - already exists
# Skipping 17.png - already exists
# Skipping 352.png - already exists
# Skipping 2117.png - already exists
# Skipping 2121.png - already exists
# Skipping 339.png - already exists
# Skipping 265.png - already exists
# Skipping 484.png - already exists
# Skipping 806.png - already exists
# Skipping 1768.png - already exists
# Skipping 272.png - already exists
# Skipping 1829.png - already exists
# Skipping 463.png - already exists
# Skipping 1050.png - already exists
# Skipping 310.png - already exists
# Skipping 322.png - already exists
# Skipping 248.png - already exists
# Skipping 1765.png - already exists
# Skipping 420.png - already exists
# Skipping 1878.png - already exists
# Skipping 308.png - already exists
# Skipping 929.png - already exists
# Skipping 4102.png - already exists
# Skipping 2120.png - already exists
# Skipping 809.png - already exists
# Skipping 2022.png - already exists
# Skipping 2765.png - already exists
# Skipping 421.png - already exists
# Skipping 198.png - already exists
# Skipping 1847.png - already exists
# Skipping 2098.png - already exists
# Skipping 802.png - already exists
# Skipping 2443.png - already exists
# Skipping 2126.png - already exists
# Skipping 1853.png - already exists
# Skipping 194.png - already exists
# Skipping 1237.png - already exists
# Skipping 1986.png - already exists
# Skipping 1895.png - already exists
# Skipping 4109.png - already exists
# Skipping 347.png - already exists
# Skipping 1821.png - already exists
# Skipping 1312.png - already exists
# Skipping 1029.png - already exists
# Skipping 278.png - already exists
# Skipping 515.png - already exists
# Skipping 202.png - already exists
# Skipping 1806.png - already exists
# Skipping 2478.png - already exists
# Skipping 1243.png - already exists
# Skipping 435.png - already exists
# Skipping 420.png - already exists
# Skipping 2692.png - already exists
# Skipping 1842.png - already exists
# Skipping 2110.png - already exists
# Skipping 871.png - already exists
# Skipping 1494.png - already exists
# Skipping 816.png - already exists
# Skipping 808.png - already exists
# Skipping 1086.png - already exists
# Skipping 2067.png - already exists
# Skipping 879.png - already exists
# Skipping 2077.png - already exists
# Skipping 3372.png - already exists
# Skipping 287.png - already exists
# Skipping 2251.png - already exists
# Skipping 2675.png - already exists
# Skipping 826.png - already exists
# Skipping 274.png - already exists
# Skipping 4839.png - already exists
# Skipping 903.png - already exists
# Skipping 854.png - already exists
# Skipping 4246.png - already exists
# Skipping 1893.png - already exists
# Skipping 860.png - already exists
# Skipping 1850.png - already exists
# Skipping 295.png - already exists
# Skipping 412.png - already exists
# Skipping 1273.png - already exists
# Skipping 1273.png - already exists
# Skipping 780.png - already exists
# Skipping 4678.png - already exists
# Skipping 2082.png - already exists
# Skipping 3485.png - already exists
# Skipping 655.png - already exists
# Skipping 1801.png - already exists
# Skipping 1970.png - already exists
# Skipping 435.png - already exists
# Skipping 31.png - already exists
# Skipping 879.png - already exists
# Skipping 2258.png - already exists
# Skipping 2097.png - already exists
# Skipping 266.png - already exists
# Skipping 1858.png - already exists
# Skipping 1761.png - already exists
# Skipping 1991.png - already exists
# Skipping 267.png - already exists
# Skipping 868.png - already exists
# Skipping 267.png - already exists
# Skipping 2731.png - already exists
# Skipping 1858.png - already exists
# Skipping 194.png - already exists
# Skipping 1456.png - already exists
# Skipping 2309.png - already exists
# Skipping 707.png - already exists
# Skipping 2012.png - already exists
# Skipping 1820.png - already exists
# Skipping 2152.png - already exists
# Skipping 2047.png - already exists
# Skipping 1899.png - already exists
# Skipping 2652.png - already exists
# Skipping 4233.png - already exists
# Skipping 1850.png - already exists
# Skipping 1979.png - already exists
# Skipping 3804.png - already exists
# Skipping 4109.png - already exists
# Skipping 1965.png - already exists
# Skipping 2273.png - already exists
# Skipping 1936.png - already exists
# Skipping 3877.png - already exists
# Skipping 1832.png - already exists
# Skipping 236.png - already exists
# Skipping 439.png - already exists
# Skipping 1174.png - already exists
# Skipping 1867.png - already exists
# Skipping 2090.png - already exists
# Skipping 2063.png - already exists
# Skipping 4658.png - already exists
# Skipping 3167.png - already exists
# Skipping 245.png - already exists
# Skipping 2078.png - already exists
# Skipping 812.png - already exists
# Skipping 4401.png - already exists
# Skipping 194.png - already exists
# Skipping 3384.png - already exists
# Skipping 3371.png - already exists
# Skipping 4572.png - already exists
# Skipping 643.png - already exists
# Skipping 1858.png - already exists
# Skipping 2531.png - already exists
# Skipping 4156.png - already exists
# Skipping 3208.png - already exists
# Skipping 901.png - already exists
# Skipping 1973.png - already exists
# Skipping 2042.png - already exists
# Skipping 470.png - already exists
# Skipping 2318.png - already exists
# Skipping 2569.png - already exists
# Skipping 20.png - already exists
# Skipping 1847.png - already exists
# Skipping 885.png - already exists
# Skipping 867.png - already exists
# Skipping 2174.png - already exists
# Skipping 246.png - already exists
# Skipping 1300.png - already exists
# Skipping 236.png - already exists
# Skipping 2617.png - already exists
# Skipping 347.png - already exists
# Skipping 2119.png - already exists
# Skipping 1766.png - already exists
# Skipping 3795.png - already exists
# Skipping 2104.png - already exists
# Skipping 2317.png - already exists
# Skipping 863.png - already exists
# Skipping 918.png - already exists
# Skipping 879.png - already exists
# Skipping 2333.png - already exists
# Skipping 1871.png - already exists
# Skipping 1907.png - already exists
# Skipping 383.png - already exists
# Skipping 244.png - already exists
# Skipping 434.png - already exists
# Skipping 2114.png - already exists
# Skipping 2130.png - already exists
# Skipping 1297.png - already exists
# Skipping 867.png - already exists
# Skipping 794.png - already exists
# Skipping 2130.png - already exists
# Skipping 908.png - already exists
# Skipping 519.png - already exists
# Skipping 2516.png - already exists
# Skipping 1764.png - already exists
# Skipping 430.png - already exists
# Skipping 1768.png - already exists
# Skipping 1978.png - already exists
# Skipping 1971.png - already exists
# Skipping 888.png - already exists
# Skipping 465.png - already exists
# Skipping 4507.png - already exists
# Skipping 100.png - already exists
# Skipping 1897.png - already exists
# Skipping 2078.png - already exists
# Skipping 3207.png - already exists
# Skipping 841.png - already exists
# Skipping 2202.png - already exists
# Skipping 2477.png - already exists
# Skipping 2744.png - already exists
# Skipping 2098.png - already exists
# Skipping 1973.png - already exists
# Skipping 1787.png - already exists
# Skipping 434.png - already exists
# Skipping 323.png - already exists
# Skipping 1752.png - already exists
# Skipping 291.png - already exists
# Skipping 2595.png - already exists
# Skipping 160.png - already exists
# Skipping 442.png - already exists
# Skipping 2061.png - already exists
# Skipping 795.png - already exists
# Skipping 554.png - already exists
# Skipping 1907.png - already exists
# Skipping 17.png - already exists
# Skipping 14.png - already exists
# Skipping 1333.png - already exists
# Skipping 794.png - already exists
# Skipping 381.png - already exists
# Skipping 880.png - already exists
# Skipping 520.png - already exists
# Skipping 270.png - already exists
# Skipping 292.png - already exists
# Skipping 2120.png - already exists
# Skipping 251.png - already exists
# Skipping 804.png - already exists
# Skipping 91.png - already exists
# Skipping 2173.png - already exists
# Skipping 1787.png - already exists
# Skipping 2600.png - already exists
# Skipping 287.png - already exists
# Skipping 1943.png - already exists
# Skipping 172.png - already exists
# Skipping 2057.png - already exists
# Skipping 2012.png - already exists
# Skipping 202.png - already exists
# Skipping 4381.png - already exists
# Skipping 1950.png - already exists
# Skipping 1768.png - already exists
# Skipping 408.png - already exists
# Skipping 3072.png - already exists
# Skipping 1936.png - already exists
# Skipping 829.png - already exists
# Skipping 1324.png - already exists
# Skipping 2263.png - already exists
# Skipping 783.png - already exists
# Skipping 801.png - already exists
# Skipping 2616.png - already exists
# Skipping 915.png - already exists
# Skipping 1967.png - already exists
# Skipping 1946.png - already exists
# Skipping 2077.png - already exists
# Skipping 917.png - already exists
# Skipping 1946.png - already exists
# Skipping 250.png - already exists
# Skipping 811.png - already exists
# Skipping 449.png - already exists
# Skipping 916.png - already exists
# Skipping 4445.png - already exists
# Skipping 806.png - already exists
# Skipping 1988.png - already exists
# Skipping 2466.png - already exists
# Skipping 464.png - already exists
# Skipping 202.png - already exists
# Skipping 897.png - already exists
# Skipping 21.png - already exists
# Skipping 2067.png - already exists
# Skipping 790.png - already exists
# Skipping 1829.png - already exists
# Skipping 1502.png - already exists
# Skipping 2263.png - already exists
# Skipping 97.png - already exists
# Skipping 444.png - already exists
# Skipping 4187.png - already exists
# Skipping 4444.png - already exists
# Skipping 251.png - already exists
# Skipping 443.png - already exists
# Skipping 253.png - already exists
# Skipping 12.png - already exists
# Skipping 4133.png - already exists
# Skipping 2193.png - already exists
# Skipping 901.png - already exists
# Skipping 1998.png - already exists
# Skipping 2569.png - already exists
# Skipping 1850.png - already exists
# Skipping 2386.png - already exists
# Skipping 4658.png - already exists
# Skipping 2011.png - already exists
# Skipping 1914.png - already exists
# Skipping 863.png - already exists
# Skipping 253.png - already exists
# Skipping 3414.png - already exists
# Skipping 1470.png - already exists
# Skipping 2330.png - already exists
# Skipping 2988.png - already exists
# Skipping 3257.png - already exists
# Skipping 1886.png - already exists
# Skipping 1297.png - already exists
# Skipping 868.png - already exists
# Skipping 2915.png - already exists
# Skipping 484.png - already exists
# Skipping 1343.png - already exists
# Skipping 499.png - already exists
# Skipping 1285.png - already exists
# Skipping 1904.png - already exists
# Skipping 2001.png - already exists
# Skipping 3165.png - already exists
# Skipping 1458.png - already exists
# Skipping 2065.png - already exists
# Skipping 3762.png - already exists
# Skipping 881.png - already exists
# Skipping 690.png - already exists
# Skipping 4701.png - already exists
# Skipping 1836.png - already exists
# Skipping 2204.png - already exists
# Skipping 790.png - already exists
# Skipping 2103.png - already exists
# Skipping 1962.png - already exists
# Skipping 903.png - already exists
# Skipping 2047.png - already exists
# Skipping 3809.png - already exists
# Skipping 3350.png - already exists
# Skipping 2352.png - already exists
# Skipping 2292.png - already exists
# Skipping 2332.png - already exists
# Skipping 4353.png - already exists
# Skipping 1994.png - already exists
# Skipping 1295.png - already exists
# Skipping 1883.png - already exists
# Skipping 1820.png - already exists
# Skipping 2937.png - already exists
# Skipping 4211.png - already exists
# Skipping 1776.png - already exists
# Skipping 817.png - already exists
# Skipping 499.png - already exists
# Skipping 301.png - already exists
# Skipping 236.png - already exists
# Skipping 266.png - already exists
# Skipping 3227.png - already exists
# Skipping 1866.png - already exists
# Skipping 868.png - already exists
# Skipping 2280.png - already exists
# Skipping 253.png - already exists
# Skipping 2016.png - already exists
# Skipping 292.png - already exists
# Skipping 2552.png - already exists
# Copied 2000 images so far...
# Skipping 2115.png - already exists
# Skipping 287.png - already exists
# Skipping 1869.png - already exists
# Skipping 2078.png - already exists
# Skipping 4775.png - already exists
# Skipping 911.png - already exists
# Skipping 1455.png - already exists
# Skipping 2130.png - already exists
# Skipping 2765.png - already exists
# Skipping 797.png - already exists
# Skipping 1765.png - already exists
# Skipping 323.png - already exists
# Skipping 2075.png - already exists
# Skipping 4513.png - already exists
# Skipping 309.png - already exists
# Skipping 287.png - already exists
# Skipping 3538.png - already exists
# Skipping 1864.png - already exists
# Skipping 1897.png - already exists
# Skipping 2233.png - already exists
# Skipping 267.png - already exists
# Skipping 3782.png - already exists
# Skipping 1778.png - already exists
# Skipping 1841.png - already exists
# Skipping 353.png - already exists
# Skipping 2032.png - already exists
# Skipping 509.png - already exists
# Skipping 867.png - already exists
# Skipping 303.png - already exists
# Skipping 1312.png - already exists
# Skipping 2193.png - already exists
# Skipping 4438.png - already exists
# Skipping 1901.png - already exists
# Skipping 872.png - already exists
# Skipping 255.png - already exists
# Skipping 826.png - already exists
# Skipping 311.png - already exists
# Skipping 2114.png - already exists
# Skipping 1237.png - already exists
# Skipping 1971.png - already exists
# Skipping 1270.png - already exists
# Skipping 517.png - already exists
# Skipping 2331.png - already exists
# Skipping 1333.png - already exists
# Skipping 161.png - already exists
# Skipping 1951.png - already exists
# Skipping 2183.png - already exists
# Skipping 356.png - already exists
# Skipping 4215.png - already exists
# Skipping 792.png - already exists
# Skipping 295.png - already exists
# Skipping 962.png - already exists
# Skipping 1903.png - already exists
# Skipping 418.png - already exists
# Skipping 1989.png - already exists
# Skipping 1168.png - already exists
# Skipping 1858.png - already exists
# Skipping 882.png - already exists
# Skipping 1839.png - already exists
# Skipping 4903.png - already exists
# Skipping 2050.png - already exists
# Skipping 14.png - already exists
# Skipping 444.png - already exists
# Skipping 832.png - already exists
# Skipping 3398.png - already exists
# Skipping 4726.png - already exists
# Skipping 2145.png - already exists
# Skipping 1785.png - already exists
# Skipping 2436.png - already exists
# Skipping 388.png - already exists
# Skipping 1951.png - already exists
# Skipping 1900.png - already exists
# Skipping 1830.png - already exists
# Skipping 2130.png - already exists
# Skipping 4603.png - already exists
# Skipping 200.png - already exists
# Skipping 270.png - already exists
# Skipping 26.png - already exists
# Skipping 1510.png - already exists
# Skipping 4881.png - already exists
# Skipping 29.png - already exists
# Skipping 1978.png - already exists
# Skipping 882.png - already exists
# Skipping 800.png - already exists
# Skipping 793.png - already exists
# Skipping 1933.png - already exists
# Skipping 2250.png - already exists
# Skipping 1852.png - already exists
# Skipping 2505.png - already exists
# Skipping 2113.png - already exists
# Skipping 629.png - already exists
# Skipping 339.png - already exists
# Skipping 536.png - already exists
# Skipping 901.png - already exists
# Skipping 593.png - already exists
# Skipping 414.png - already exists
# Skipping 1785.png - already exists
# Skipping 612.png - already exists
# Skipping 4142.png - already exists
# Skipping 822.png - already exists
# Skipping 4611.png - already exists
# Skipping 1282.png - already exists
# Skipping 2674.png - already exists
# Skipping 4503.png - already exists
# Skipping 2190.png - already exists
# Skipping 449.png - already exists
# Skipping 1388.png - already exists
# Skipping 20.png - already exists
# Skipping 517.png - already exists
# Skipping 1255.png - already exists
# Skipping 148.png - already exists
# Skipping 486.png - already exists
# Skipping 1859.png - already exists
# Skipping 2061.png - already exists
# Skipping 2006.png - already exists
# Skipping 4124.png - already exists
# Skipping 1821.png - already exists
# Skipping 1977.png - already exists
# Skipping 298.png - already exists
# Skipping 203.png - already exists
# Skipping 497.png - already exists
# Skipping 509.png - already exists
# Skipping 2173.png - already exists
# Skipping 443.png - already exists
# Skipping 2100.png - already exists
# Skipping 2067.png - already exists
# Skipping 911.png - already exists
# Skipping 865.png - already exists
# Skipping 2318.png - already exists
# Skipping 2416.png - already exists
# Skipping 1785.png - already exists
# Skipping 2107.png - already exists
# Skipping 2056.png - already exists
# Skipping 260.png - already exists
# Skipping 2007.png - already exists
# Skipping 1876.png - already exists
# Skipping 2883.png - already exists
# Skipping 311.png - already exists
# Skipping 1766.png - already exists
# Skipping 1343.png - already exists
# Skipping 414.png - already exists
# Skipping 1312.png - already exists
# Skipping 1990.png - already exists
# Skipping 1973.png - already exists
# Skipping 707.png - already exists
# Skipping 272.png - already exists
# Skipping 4211.png - already exists
# Skipping 1263.png - already exists
# Skipping 347.png - already exists
# Skipping 255.png - already exists
# Skipping 1762.png - already exists
# Skipping 198.png - already exists
# Skipping 26.png - already exists
# Skipping 1967.png - already exists
# Skipping 708.png - already exists
# Skipping 274.png - already exists
# Skipping 938.png - already exists
# Skipping 1788.png - already exists
# Skipping 1847.png - already exists
# Skipping 309.png - already exists
# Skipping 873.png - already exists
# Skipping 4135.png - already exists
# Skipping 4796.png - already exists
# Skipping 1858.png - already exists
# Skipping 3232.png - already exists
# Skipping 488.png - already exists
# Skipping 1838.png - already exists
# Skipping 4879.png - already exists
# Skipping 4186.png - already exists
# Skipping 4132.png - already exists
# Skipping 1760.png - already exists
# Skipping 887.png - already exists
# Skipping 414.png - already exists
# Skipping 3797.png - already exists
# Skipping 4612.png - already exists
# Skipping 4109.png - already exists
# Skipping 29.png - already exists
# Skipping 2443.png - already exists
# Skipping 307.png - already exists
# Skipping 2192.png - already exists
# Skipping 1144.png - already exists
# Skipping 2214.png - already exists
# Skipping 1742.png - already exists
# Skipping 432.png - already exists
# Skipping 486.png - already exists
# Skipping 792.png - already exists
# Skipping 289.png - already exists
# Skipping 1042.png - already exists
# Skipping 822.png - already exists
# Skipping 2230.png - already exists
# Skipping 2190.png - already exists
# Skipping 1791.png - already exists
# Skipping 412.png - already exists
# Skipping 1960.png - already exists
# Skipping 2115.png - already exists
# Skipping 1917.png - already exists
# Skipping 423.png - already exists
# Skipping 54.png - already exists
# Skipping 236.png - already exists
# Skipping 1839.png - already exists
# Skipping 2454.png - already exists
# Skipping 821.png - already exists
# Skipping 301.png - already exists
# Skipping 1762.png - already exists
# Skipping 2606.png - already exists
# Skipping 1863.png - already exists
# Skipping 307.png - already exists
# Skipping 1984.png - already exists
# Skipping 2403.png - already exists
# Skipping 908.png - already exists
# Skipping 1803.png - already exists
# Skipping 802.png - already exists
# Skipping 1441.png - already exists
# Skipping 248.png - already exists
# Skipping 1793.png - already exists
# Skipping 1762.png - already exists
# Skipping 2362.png - already exists
# Skipping 2303.png - already exists
# Skipping 1978.png - already exists
# Skipping 2853.png - already exists
# Skipping 262.png - already exists
# Skipping 499.png - already exists
# Skipping 1297.png - already exists
# Skipping 4218.png - already exists
# Skipping 888.png - already exists
# Skipping 2001.png - already exists
# Skipping 404.png - already exists
# Skipping 1929.png - already exists
# Skipping 872.png - already exists
# Skipping 1143.png - already exists
# Skipping 815.png - already exists
# Skipping 4388.png - already exists
# Skipping 238.png - already exists
# Skipping 1876.png - already exists
# Skipping 2152.png - already exists
# Skipping 3762.png - already exists
# Skipping 2668.png - already exists
# Skipping 642.png - already exists
# Skipping 911.png - already exists
# Skipping 296.png - already exists
# Skipping 2115.png - already exists
# Skipping 3591.png - already exists
# Skipping 443.png - already exists
# Skipping 2548.png - already exists
# Skipping 166.png - already exists
# Skipping 2009.png - already exists
# Skipping 711.png - already exists
# Skipping 431.png - already exists
# Skipping 315.png - already exists
# Skipping 2226.png - already exists
# Skipping 1407.png - already exists
# Skipping 2122.png - already exists
# Skipping 1957.png - already exists
# Skipping 287.png - already exists
# Skipping 2503.png - already exists
# Skipping 590.png - already exists
# Skipping 3769.png - already exists
# Skipping 14.png - already exists
# Skipping 1908.png - already exists
# Skipping 1989.png - already exists
# Skipping 2317.png - already exists
# Skipping 903.png - already exists
# Skipping 1849.png - already exists
# Skipping 1918.png - already exists
# Skipping 2069.png - already exists
# Skipping 1882.png - already exists
# Skipping 2090.png - already exists
# Skipping 2001.png - already exists
# Skipping 1998.png - already exists
# Skipping 498.png - already exists
# Skipping 3442.png - already exists
# Skipping 538.png - already exists
# Skipping 4388.png - already exists
# Skipping 3825.png - already exists
# Skipping 2372.png - already exists
# Skipping 264.png - already exists
# Skipping 262.png - already exists
# Skipping 2542.png - already exists
# Skipping 2055.png - already exists
# Skipping 2394.png - already exists
# Skipping 904.png - already exists
# Skipping 2567.png - already exists
# Skipping 3595.png - already exists
# Skipping 4052.png - already exists
# Skipping 2174.png - already exists
# Skipping 509.png - already exists
# Skipping 2230.png - already exists
# Skipping 886.png - already exists
# Skipping 2457.png - already exists
# Skipping 1816.png - already exists
# Skipping 3612.png - already exists
# Skipping 2545.png - already exists
# Skipping 2057.png - already exists
# Skipping 2268.png - already exists
# Skipping 435.png - already exists
# Skipping 236.png - already exists
# Skipping 2116.png - already exists
# Skipping 3188.png - already exists
# Skipping 2305.png - already exists
# Skipping 2082.png - already exists
# Skipping 2200.png - already exists
# Skipping 194.png - already exists
# Skipping 923.png - already exists
# Skipping 418.png - already exists
# Skipping 901.png - already exists
# Skipping 2516.png - already exists
# Skipping 482.png - already exists
# Skipping 1245.png - already exists
# Skipping 1101.png - already exists
# Skipping 1300.png - already exists
# Skipping 1316.png - already exists
# Skipping 1929.png - already exists
# Skipping 873.png - already exists
# Skipping 1778.png - already exists
# Skipping 2065.png - already exists
# Skipping 432.png - already exists
# Skipping 4090.png - already exists
# Skipping 2100.png - already exists
# Skipping 245.png - already exists
# Skipping 48.png - already exists
# Skipping 2117.png - already exists
# Skipping 2146.png - already exists
# Skipping 929.png - already exists
# Skipping 1977.png - already exists
# Skipping 3500.png - already exists
# Skipping 1777.png - already exists
# Skipping 1361.png - already exists
# Skipping 1335.png - already exists
# Skipping 1994.png - already exists
# Skipping 515.png - already exists
# Skipping 1243.png - already exists
# Skipping 2097.png - already exists
# Skipping 2526.png - already exists
# Skipping 2646.png - already exists
# Skipping 26.png - already exists
# Skipping 2096.png - already exists
# Skipping 1852.png - already exists
# Skipping 3922.png - already exists
# Skipping 317.png - already exists
# Skipping 515.png - already exists
# Skipping 1114.png - already exists
# Skipping 2575.png - already exists
# Skipping 200.png - already exists
# Skipping 587.png - already exists
# Skipping 1802.png - already exists
# Skipping 2305.png - already exists
# Skipping 62.png - already exists
# Skipping 318.png - already exists
# Skipping 2087.png - already exists
# Skipping 2078.png - already exists
# Skipping 1800.png - already exists
# Skipping 93.png - already exists
# Skipping 290.png - already exists
# Skipping 1862.png - already exists
# Skipping 2691.png - already exists
# Skipping 72.png - already exists
# Skipping 1935.png - already exists
# Skipping 2474.png - already exists
# Skipping 289.png - already exists
# Skipping 497.png - already exists
# Skipping 4514.png - already exists
# Skipping 449.png - already exists
# Skipping 4090.png - already exists
# Skipping 2116.png - already exists
# Skipping 2636.png - already exists
# Skipping 1944.png - already exists
# Skipping 873.png - already exists
# Skipping 1441.png - already exists
# Skipping 924.png - already exists
# Skipping 2709.png - already exists
# Skipping 2275.png - already exists
# Skipping 235.png - already exists
# Skipping 1820.png - already exists
# Skipping 2711.png - already exists
# Skipping 3432.png - already exists
# Skipping 4597.png - already exists
# Skipping 1482.png - already exists
# Skipping 1914.png - already exists
# Skipping 317.png - already exists
# Skipping 317.png - already exists
# Skipping 1146.png - already exists
# Skipping 956.png - already exists
# Skipping 1900.png - already exists
# Skipping 2342.png - already exists
# Skipping 1786.png - already exists
# Skipping 3877.png - already exists
# Skipping 867.png - already exists
# Skipping 2115.png - already exists
# Skipping 419.png - already exists
# Skipping 1864.png - already exists
# Skipping 620.png - already exists
# Skipping 2070.png - already exists
# Skipping 519.png - already exists
# Skipping 477.png - already exists
# Skipping 1388.png - already exists
# Skipping 2569.png - already exists
# Skipping 4158.png - already exists
# Skipping 2041.png - already exists
# Skipping 1962.png - already exists
# Skipping 1698.png - already exists
# Skipping 891.png - already exists
# Skipping 2127.png - already exists
# Skipping 2435.png - already exists
# Skipping 469.png - already exists
# Skipping 3227.png - already exists
# Skipping 468.png - already exists
# Skipping 422.png - already exists
# Skipping 2394.png - already exists
# Skipping 2107.png - already exists
# Skipping 295.png - already exists
# Skipping 466.png - already exists
# Skipping 4642.png - already exists
# Skipping 425.png - already exists
# Skipping 938.png - already exists
# Skipping 1833.png - already exists
# Skipping 2006.png - already exists
# Skipping 1774.png - already exists
# Skipping 910.png - already exists
# Skipping 322.png - already exists
# Skipping 2010.png - already exists
# Skipping 861.png - already exists
# Skipping 497.png - already exists
# Skipping 260.png - already exists
# Skipping 4311.png - already exists
# Skipping 241.png - already exists
# Skipping 2309.png - already exists
# Skipping 1884.png - already exists
# Skipping 3722.png - already exists
# Skipping 3746.png - already exists
# Skipping 914.png - already exists
# Skipping 3979.png - already exists
# Skipping 813.png - already exists
# Skipping 29.png - already exists
# Skipping 1802.png - already exists
# Skipping 2354.png - already exists
# Skipping 1830.png - already exists
# Skipping 1897.png - already exists
# Skipping 422.png - already exists
# Skipping 3149.png - already exists
# Skipping 3188.png - already exists
# Skipping 1862.png - already exists
# Skipping 1845.png - already exists
# Skipping 1770.png - already exists
# Skipping 839.png - already exists
# Skipping 287.png - already exists
# Skipping 2578.png - already exists
# Skipping 270.png - already exists
# Skipping 1083.png - already exists
# Skipping 2672.png - already exists
# Skipping 1479.png - already exists
# Skipping 3975.png - already exists
# Skipping 115.png - already exists
# Skipping 3657.png - already exists
# Skipping 2596.png - already exists
# Skipping 236.png - already exists
# Skipping 826.png - already exists
# Skipping 2057.png - already exists
# Skipping 239.png - already exists
# Skipping 1342.png - already exists
# Skipping 4268.png - already exists
# Skipping 937.png - already exists
# Skipping 1981.png - already exists
# Skipping 1936.png - already exists
# Skipping 291.png - already exists
# Skipping 2283.png - already exists
# Skipping 1967.png - already exists
# Skipping 274.png - already exists
# Skipping 989.png - already exists
# Skipping 1039.png - already exists
# Skipping 2331.png - already exists
# Skipping 1245.png - already exists
# Skipping 2105.png - already exists
# Skipping 797.png - already exists
# Skipping 1867.png - already exists
# Skipping 752.png - already exists
# Skipping 4651.png - already exists
# Skipping 50.png - already exists
# Skipping 811.png - already exists
# Skipping 318.png - already exists
# Skipping 813.png - already exists
# Skipping 516.png - already exists
# Skipping 2047.png - already exists
# Skipping 3617.png - already exists
# Skipping 428.png - already exists
# Skipping 2044.png - already exists
# Skipping 2114.png - already exists
# Skipping 2728.png - already exists
# Skipping 4154.png - already exists
# Skipping 880.png - already exists
# Skipping 260.png - already exists
# Skipping 2033.png - already exists
# Skipping 2107.png - already exists
# Skipping 435.png - already exists
# Skipping 817.png - already exists
# Skipping 1485.png - already exists
# Skipping 511.png - already exists
# Skipping 492.png - already exists
# Skipping 29.png - already exists
# Skipping 2433.png - already exists
# Skipping 1877.png - already exists
# Skipping 4098.png - already exists
# Skipping 4049.png - already exists
# Skipping 2107.png - already exists
# Skipping 2012.png - already exists
# Skipping 4158.png - already exists
# Skipping 1940.png - already exists
# Skipping 4095.png - already exists
# Skipping 3680.png - already exists
# Skipping 945.png - already exists
# Skipping 1438.png - already exists
# Skipping 2006.png - already exists
# Skipping 2514.png - already exists
# Skipping 4133.png - already exists
# Skipping 1388.png - already exists
# Skipping 2427.png - already exists
# Skipping 4663.png - already exists
# Skipping 4147.png - already exists
# Skipping 1848.png - already exists
# Skipping 1807.png - already exists
# Skipping 4161.png - already exists
# Skipping 268.png - already exists
# Skipping 1965.png - already exists
# Skipping 4612.png - already exists
# Skipping 1883.png - already exists
# Skipping 2063.png - already exists
# Skipping 2172.png - already exists
# Skipping 1468.png - already exists
# Skipping 722.png - already exists
# Skipping 4134.png - already exists
# Skipping 2372.png - already exists
# Skipping 23.png - already exists
# Skipping 4793.png - already exists
# Skipping 25.png - already exists
# Skipping 737.png - already exists
# Skipping 272.png - already exists
# Skipping 2735.png - already exists
# Skipping 4643.png - already exists
# Skipping 1845.png - already exists
# Skipping 3127.png - already exists
# Skipping 242.png - already exists
# Skipping 749.png - already exists
# Skipping 1949.png - already exists
# Skipping 863.png - already exists
# Skipping 1867.png - already exists
# Skipping 3062.png - already exists
# Skipping 63.png - already exists
# Skipping 2033.png - already exists
# Skipping 1994.png - already exists
# Skipping 4134.png - already exists
# Skipping 3725.png - already exists
# Skipping 827.png - already exists
# Skipping 1627.png - already exists
# Skipping 4659.png - already exists
# Skipping 2525.png - already exists
# Skipping 1978.png - already exists
# Skipping 321.png - already exists
# Skipping 1787.png - already exists
# Skipping 4668.png - already exists
# Skipping 292.png - already exists
# Skipping 1236.png - already exists
# Skipping 1245.png - already exists
# Skipping 811.png - already exists
# Skipping 1821.png - already exists
# Skipping 506.png - already exists
# Skipping 2113.png - already exists
# Skipping 1864.png - already exists
# Skipping 2003.png - already exists
# Skipping 1967.png - already exists
# Skipping 476.png - already exists
# Skipping 3878.png - already exists
# Skipping 300.png - already exists
# Skipping 3809.png - already exists
# Skipping 790.png - already exists
# Skipping 1769.png - already exists
# Skipping 269.png - already exists
# Skipping 1043.png - already exists
# Skipping 4366.png - already exists
# Skipping 131.png - already exists
# Skipping 615.png - already exists
# Skipping 1863.png - already exists
# Skipping 4175.png - already exists
# Skipping 154.png - already exists
# Skipping 990.png - already exists
# Skipping 2126.png - already exists
# Skipping 936.png - already exists
# Skipping 296.png - already exists
# Skipping 17.png - already exists
# Skipping 2318.png - already exists
# Skipping 3500.png - already exists
# Skipping 2279.png - already exists
# Skipping 1998.png - already exists
# Skipping 2126.png - already exists
# Skipping 1128.png - already exists
# Skipping 4090.png - already exists
# Skipping 2396.png - already exists
# Skipping 198.png - already exists
# Skipping 2003.png - already exists
# Skipping 308.png - already exists
# Skipping 4760.png - already exists
# Skipping 769.png - already exists
# Skipping 2187.png - already exists
# Skipping 4059.png - already exists
# Skipping 593.png - already exists
# Skipping 244.png - already exists
# Skipping 804.png - already exists
# Skipping 2340.png - already exists
# Skipping 290.png - already exists
# Skipping 440.png - already exists
# Skipping 425.png - already exists
# Skipping 2094.png - already exists
# Skipping 4441.png - already exists
# Skipping 4215.png - already exists
# Skipping 1342.png - already exists
# Skipping 1834.png - already exists
# Skipping 4657.png - already exists
# Skipping 4111.png - already exists
# Skipping 1981.png - already exists
# Skipping 268.png - already exists
# Skipping 2038.png - already exists
# Skipping 2436.png - already exists
# Skipping 283.png - already exists
# Skipping 435.png - already exists
# Skipping 3701.png - already exists
# Skipping 1981.png - already exists
# Skipping 318.png - already exists
# Skipping 1863.png - already exists
# Skipping 4572.png - already exists
# Skipping 865.png - already exists
# Skipping 261.png - already exists
# Skipping 2293.png - already exists
# Skipping 1894.png - already exists
# Skipping 2280.png - already exists
# Skipping 1894.png - already exists
# Skipping 1308.png - already exists
# Skipping 1838.png - already exists
# Skipping 1940.png - already exists
# Skipping 741.png - already exists
# Skipping 3617.png - already exists
# Skipping 425.png - already exists
# Skipping 4386.png - already exists
# Skipping 1833.png - already exists
# Skipping 2079.png - already exists
# Skipping 706.png - already exists
# Skipping 300.png - already exists
# Skipping 498.png - already exists
# Skipping 443.png - already exists
# Skipping 1884.png - already exists
# Skipping 800.png - already exists
# Skipping 1893.png - already exists
# Skipping 2119.png - already exists
# Skipping 1676.png - already exists
# Skipping 168.png - already exists
# Skipping 4619.png - already exists
# Skipping 4441.png - already exists
# Skipping 388.png - already exists
# Skipping 236.png - already exists
# Skipping 432.png - already exists
# Skipping 2574.png - already exists
# Skipping 2126.png - already exists
# Skipping 2104.png - already exists
# Skipping 1393.png - already exists
# Skipping 1407.png - already exists
# Skipping 315.png - already exists
# Skipping 512.png - already exists
# Skipping 1815.png - already exists
# Skipping 1855.png - already exists
# Skipping 918.png - already exists
# Skipping 2652.png - already exists
# Skipping 1858.png - already exists
# Skipping 2098.png - already exists
# Skipping 794.png - already exists
# Skipping 1793.png - already exists
# Skipping 422.png - already exists
# Skipping 388.png - already exists
# Skipping 4079.png - already exists
# Skipping 414.png - already exists
# Skipping 2590.png - already exists
# Skipping 2157.png - already exists
# Skipping 2011.png - already exists
# Skipping 23.png - already exists
# Skipping 2429.png - already exists
# Skipping 270.png - already exists
# Skipping 2012.png - already exists
# Skipping 91.png - already exists
# Skipping 4193.png - already exists
# Skipping 352.png - already exists
# Skipping 1210.png - already exists
# Skipping 1245.png - already exists
# Skipping 4320.png - already exists
# Skipping 1894.png - already exists
# Skipping 1903.png - already exists
# Skipping 1296.png - already exists
# Skipping 2100.png - already exists
# Skipping 1959.png - already exists
# Skipping 875.png - already exists
# Skipping 62.png - already exists
# Skipping 317.png - already exists
# Skipping 2008.png - already exists
# Skipping 2157.png - already exists
# Skipping 1977.png - already exists
# Skipping 816.png - already exists
# Skipping 473.png - already exists
# Skipping 1861.png - already exists
# Skipping 1998.png - already exists
# Skipping 1700.png - already exists
# Skipping 3941.png - already exists
# Skipping 4333.png - already exists
# Skipping 2109.png - already exists
# Skipping 2019.png - already exists
# Skipping 1932.png - already exists
# Skipping 820.png - already exists
# Skipping 1821.png - already exists
# Skipping 2055.png - already exists
# Skipping 1942.png - already exists
# Skipping 2056.png - already exists
# Skipping 2404.png - already exists
# Skipping 292.png - already exists
# Skipping 1871.png - already exists
# Skipping 2308.png - already exists
# Skipping 1981.png - already exists
# Skipping 2008.png - already exists
# Skipping 3160.png - already exists
# Skipping 2016.png - already exists
# Skipping 270.png - already exists
# Skipping 588.png - already exists
# Skipping 132.png - already exists
# Skipping 1766.png - already exists
# Skipping 66.png - already exists
# Skipping 2109.png - already exists
# Skipping 1321.png - already exists
# Skipping 1984.png - already exists
# Skipping 323.png - already exists
# Skipping 3028.png - already exists
# Skipping 4590.png - already exists
# Skipping 2660.png - already exists
# Skipping 2538.png - already exists
# Skipping 2230.png - already exists
# Skipping 21.png - already exists
# Skipping 2032.png - already exists
# Skipping 516.png - already exists
# Skipping 2073.png - already exists
# Skipping 317.png - already exists
# Skipping 1310.png - already exists
# Skipping 816.png - already exists
# Skipping 1042.png - already exists
# Skipping 4419.png - already exists
# Skipping 2113.png - already exists
# Skipping 2050.png - already exists
# Skipping 2016.png - already exists
# Skipping 2484.png - already exists
# Skipping 2502.png - already exists
# Skipping 308.png - already exists
# Skipping 2160.png - already exists
# Skipping 532.png - already exists
# Skipping 1928.png - already exists
# Skipping 691.png - already exists
# Skipping 1978.png - already exists
# Skipping 443.png - already exists
# Skipping 494.png - already exists
# Skipping 61.png - already exists
# Skipping 933.png - already exists
# Skipping 2689.png - already exists
# Skipping 1989.png - already exists
# Skipping 2113.png - already exists
# Skipping 3029.png - already exists
# Skipping 73.png - already exists
# Skipping 2064.png - already exists
# Skipping 253.png - already exists
# Skipping 4651.png - already exists
# Skipping 914.png - already exists
# Skipping 1984.png - already exists
# Skipping 3911.png - already exists
# Skipping 811.png - already exists
# Skipping 89.png - already exists
# Skipping 3379.png - already exists
# Skipping 2462.png - already exists
# Skipping 1793.png - already exists
# Skipping 100.png - already exists
# Skipping 29.png - already exists
# ...
# Skipping 2323.png - already exists
# Skipping 236.png - already exists
# Skipping 2077.png - already exists
# Skipping 1901.png - already exists
# Skipping 3924.png - already exists
# Skipping 1875.png - already exists
# Skipping 615.png - already exists
# Skipping 1311.png - already exists
# Skipping 1855.png - already exists
# Skipping 25.png - already exists
# Skipping 1763.png - already exists
# Skipping 292.png - already exists
# Skipping 4180.png - already exists
# Skipping 1914.png - already exists
# Skipping 2365.png - already exists
# Skipping 1381.png - already exists
# Skipping 4092.png - already exists
# Skipping 3697.png - already exists
# Skipping 2098.png - already exists
# Skipping 2069.png - already exists
# Skipping 2541.png - already exists
# Skipping 83.png - already exists
# Skipping 908.png - already exists
# Skipping 4679.png - already exists
# Skipping 4335.png - already exists
# Skipping 4293.png - already exists
# Skipping 3918.png - already exists
# Skipping 4150.png - already exists
# Skipping 2733.png - already exists
# Skipping 164.png - already exists
# Skipping 815.png - already exists
# Skipping 2217.png - already exists
# Skipping 1769.png - already exists
# Skipping 3501.png - already exists
# Skipping 657.png - already exists
# Skipping 2242.png - already exists
# Skipping 1708.png - already exists
# Skipping 2377.png - already exists
# Skipping 4744.png - already exists
# Skipping 861.png - already exists
# Skipping 4743.png - already exists
# Skipping 512.png - already exists
# Skipping 519.png - already exists
# Skipping 1098.png - already exists
# Skipping 467.png - already exists
# Skipping 198.png - already exists
# Skipping 2337.png - already exists
# Skipping 4525.png - already exists
# Skipping 17.png - already exists
# Skipping 2595.png - already exists
# Skipping 2266.png - already exists
# Skipping 4717.png - already exists
# Skipping 879.png - already exists
# Skipping 4180.png - already exists
# Skipping 571.png - already exists
# Skipping 62.png - already exists
# Skipping 1877.png - already exists
# Skipping 311.png - already exists
# Skipping 2969.png - already exists
# Skipping 2087.png - already exists
# Skipping 4136.png - already exists
# Skipping 601.png - already exists
# Skipping 4322.png - already exists
# Skipping 1844.png - already exists
# Skipping 2103.png - already exists
# Skipping 1865.png - already exists
# Skipping 1884.png - already exists
# Skipping 1791.png - already exists
# Skipping 2411.png - already exists
# Skipping 245.png - already exists
# Skipping 3719.png - already exists
# Skipping 426.png - already exists
# Skipping 807.png - already exists
# Skipping 1955.png - already exists
# Skipping 194.png - already exists
# Skipping 1342.png - already exists
# Skipping 1912.png - already exists
# Skipping 4258.png - already exists
# Skipping 2765.png - already exists
# Skipping 268.png - already exists
# Skipping 1957.png - already exists
# Skipping 4087.png - already exists
# Skipping 1699.png - already exists
# Skipping 2497.png - already exists
# Skipping 897.png - already exists
# Skipping 2845.png - already exists
# Skipping 2845.png - already exists
# Skipping 2038.png - already exists
# Skipping 968.png - already exists
# Skipping 797.png - already exists
# Skipping 4503.png - already exists
# Skipping 3421.png - already exists
# Skipping 4106.png - already exists
# Skipping 2127.png - already exists
# Skipping 399.png - already exists
# Skipping 3932.png - already exists
# Skipping 1271.png - already exists
# Skipping 2526.png - already exists
# Skipping 4209.png - already exists
# Skipping 151.png - already exists
# Skipping 305.png - already exists
# Skipping 4452.png - already exists
# Skipping 4103.png - already exists
# Skipping 2016.png - already exists
# Skipping 468.png - already exists
# Skipping 2096.png - already exists
# Skipping 636.png - already exists
# Skipping 882.png - already exists
# Skipping 1190.png - already exists
# Skipping 512.png - already exists
# Skipping 4733.png - already exists
# Skipping 2396.png - already exists
# Skipping 145.png - already exists
# Skipping 1853.png - already exists
# Skipping 4311.png - already exists
# Skipping 2706.png - already exists
# Skipping 1347.png - already exists
# Skipping 428.png - already exists
# Skipping 1864.png - already exists
# Skipping 2111.png - already exists
# Skipping 4738.png - already exists
# Skipping 2400.png - already exists
# Skipping 4439.png - already exists
# Skipping 508.png - already exists
# Skipping 3247.png - already exists
# Skipping 3655.png - already exists
# Skipping 1846.png - already exists
# Skipping 911.png - already exists
# Skipping 4138.png - already exists
# Skipping 4458.png - already exists
# Skipping 807.png - already exists
# Skipping 399.png - already exists
# Skipping 2207.png - already exists
# Skipping 2114.png - already exists
# Skipping 2564.png - already exists
# Skipping 412.png - already exists
# Skipping 2267.png - already exists
# Skipping 4320.png - already exists
# Skipping 2319.png - already exists
# Skipping 4759.png - already exists
# Skipping 421.png - already exists
# Skipping 2120.png - already exists
# Skipping 246.png - already exists
# Skipping 4596.png - already exists
# Skipping 1971.png - already exists
# Skipping 3584.png - already exists
# Skipping 910.png - already exists
# Skipping 661.png - already exists
# Skipping 2756.png - already exists
# Skipping 2887.png - already exists
# Skipping 610.png - already exists
# Skipping 482.png - already exists
# Skipping 584.png - already exists
# Skipping 2897.png - already exists
# Skipping 4657.png - already exists
# Skipping 867.png - already exists
# Skipping 2303.png - already exists
# Skipping 809.png - already exists
# Skipping 1912.png - already exists
# Skipping 2259.png - already exists
# Skipping 2088.png - already exists
# Skipping 2009.png - already exists
# Skipping 1765.png - already exists
# Skipping 1645.png - already exists
# Skipping 2387.png - already exists
# Skipping 1466.png - already exists
# Skipping 2680.png - already exists
# Skipping 904.png - already exists
# Skipping 1757.png - already exists
# Skipping 2056.png - already exists
# Skipping 247.png - already exists
# Skipping 1867.png - already exists
# Skipping 436.png - already exists
# Skipping 688.png - already exists
# Skipping 1815.png - already exists
# Skipping 2153.png - already exists
# Skipping 937.png - already exists
# Skipping 2094.png - already exists
# Skipping 2004.png - already exists
# Skipping 1278.png - already exists
# Skipping 4606.png - already exists
# Skipping 4210.png - already exists
# Skipping 3474.png - already exists
# Skipping 1316.png - already exists
# Skipping 381.png - already exists
# Skipping 2053.png - already exists
# Skipping 1492.png - already exists
# Skipping 2033.png - already exists
# Skipping 896.png - already exists
# Skipping 1802.png - already exists
# Skipping 2719.png - already exists
# Skipping 304.png - already exists
# Skipping 1820.png - already exists
# Skipping 4400.png - already exists
# Skipping 2630.png - already exists
# Skipping 3030.png - already exists
# Skipping 4447.png - already exists
# Skipping 398.png - already exists
# Skipping 4446.png - already exists
# Skipping 4519.png - already exists
# Skipping 1013.png - already exists
# Skipping 2959.png - already exists
# Skipping 1971.png - already exists
# Skipping 2271.png - already exists
# Skipping 1121.png - already exists
# Skipping 511.png - already exists
# Skipping 4357.png - already exists
# Skipping 388.png - already exists
# Skipping 923.png - already exists
# Skipping 16.png - already exists
# Skipping 2046.png - already exists
# Skipping 4410.png - already exists
# Skipping 749.png - already exists
# Skipping 929.png - already exists
# Skipping 139.png - already exists
# Skipping 2756.png - already exists
# Skipping 250.png - already exists
# Skipping 1838.png - already exists
# Skipping 517.png - already exists
# Skipping 4268.png - already exists
# Skipping 3907.png - already exists
# Skipping 1271.png - already exists
# Skipping 265.png - already exists
# Skipping 2546.png - already exists
# Skipping 905.png - already exists
# Skipping 3800.png - already exists
# Skipping 253.png - already exists
# Skipping 3957.png - already exists
# Skipping 87.png - already exists
# Skipping 260.png - already exists
# Skipping 808.png - already exists
# Skipping 897.png - already exists
# Skipping 4467.png - already exists
# Skipping 2024.png - already exists
# Skipping 2315.png - already exists
# Skipping 716.png - already exists
# Skipping 2652.png - already exists
# Skipping 3974.png - already exists
# Skipping 1869.png - already exists
# Skipping 435.png - already exists
# Skipping 2397.png - already exists
# Skipping 198.png - already exists
# Skipping 1946.png - already exists
# Skipping 3084.png - already exists
# Skipping 698.png - already exists
# Skipping 2476.png - already exists
# Skipping 2015.png - already exists
# Skipping 3991.png - already exists
# Skipping 4412.png - already exists
# Skipping 2293.png - already exists
# Skipping 3480.png - already exists
# Skipping 352.png - already exists
# Skipping 325.png - already exists
# Skipping 1915.png - already exists
# Skipping 2073.png - already exists
# Skipping 1883.png - already exists
# Skipping 1813.png - already exists
# Skipping 445.png - already exists
# Skipping 1037.png - already exists
# Skipping 1800.png - already exists
# Skipping 4164.png - already exists
# Skipping 4091.png - already exists
# Skipping 913.png - already exists
# Skipping 716.png - already exists
# Skipping 1345.png - already exists
# Skipping 315.png - already exists
# Skipping 2704.png - already exists
# Skipping 289.png - already exists
# Skipping 492.png - already exists
# Skipping 503.png - already exists
# Skipping 1632.png - already exists
# Skipping 914.png - already exists
# Skipping 1807.png - already exists
# Skipping 2330.png - already exists
# Skipping 917.png - already exists
# Skipping 1821.png - already exists
# Skipping 175.png - already exists
# Skipping 2202.png - already exists
# Skipping 600.png - already exists
# Skipping 558.png - already exists
# Skipping 2087.png - already exists
# Skipping 4619.png - already exists
# Skipping 597.png - already exists
# Skipping 797.png - already exists
# Skipping 1738.png - already exists
# Skipping 973.png - already exists
# Skipping 2971.png - already exists
# Skipping 432.png - already exists
# Skipping 470.png - already exists
# Skipping 515.png - already exists
# Skipping 1460.png - already exists
# Skipping 928.png - already exists
# Skipping 4562.png - already exists
# Skipping 4503.png - already exists
# Skipping 1820.png - already exists
# Skipping 4394.png - already exists
# Skipping 3497.png - already exists
# Skipping 1044.png - already exists
# Skipping 917.png - already exists
# Skipping 2098.png - already exists
# Skipping 1641.png - already exists
# Skipping 2125.png - already exists
# Skipping 2415.png - already exists
# Skipping 245.png - already exists
# Skipping 1293.png - already exists
# Skipping 1975.png - already exists
# Skipping 1243.png - already exists
# Skipping 488.png - already exists
# Skipping 1716.png - already exists
# Skipping 4694.png - already exists
# Skipping 1339.png - already exists
# Skipping 3179.png - already exists
# Skipping 1944.png - already exists
# Skipping 1788.png - already exists
# Skipping 497.png - already exists
# Skipping 4693.png - already exists
# Skipping 1913.png - already exists
# Skipping 269.png - already exists
# Skipping 975.png - already exists
# Skipping 4222.png - already exists
# Skipping 2228.png - already exists
# Skipping 1525.png - already exists
# Skipping 3554.png - already exists
# Skipping 2585.png - already exists
# Skipping 2530.png - already exists
# Skipping 1991.png - already exists
# Skipping 1969.png - already exists
# Skipping 322.png - already exists
# Skipping 1355.png - already exists
# Skipping 1912.png - already exists
# Skipping 535.png - already exists
# Skipping 2016.png - already exists
# Skipping 811.png - already exists
# Skipping 2510.png - already exists
# Skipping 804.png - already exists
# Skipping 248.png - already exists
# Skipping 4051.png - already exists
# Skipping 4408.png - already exists
# Skipping 1967.png - already exists
# Skipping 4820.png - already exists
# Skipping 301.png - already exists
# Skipping 3322.png - already exists
# Skipping 802.png - already exists
# Skipping 1848.png - already exists
# Skipping 2234.png - already exists
# Skipping 1323.png - already exists
# Skipping 1942.png - already exists
# Skipping 4182.png - already exists
# Skipping 419.png - already exists
# Skipping 114.png - already exists
# Skipping 3379.png - already exists
# Skipping 2654.png - already exists
# Skipping 2114.png - already exists
# Skipping 202.png - already exists
# Skipping 997.png - already exists
# Skipping 2149.png - already exists
# Skipping 533.png - already exists
# Skipping 3679.png - already exists
# Skipping 1220.png - already exists
# Skipping 2481.png - already exists
# Skipping 312.png - already exists
# Skipping 4294.png - already exists
# Skipping 2553.png - already exists
# Skipping 1823.png - already exists
# Skipping 108.png - already exists
# Skipping 2087.png - already exists
# Skipping 558.png - already exists
# Skipping 4721.png - already exists
# Skipping 2719.png - already exists
# Skipping 4180.png - already exists
# Skipping 291.png - already exists
# Skipping 401.png - already exists
# Skipping 772.png - already exists
# Skipping 510.png - already exists
# Skipping 506.png - already exists
# Skipping 2065.png - already exists
# Skipping 820.png - already exists
# Skipping 101.png - already exists
# Skipping 2019.png - already exists
# Skipping 419.png - already exists
# Skipping 4684.png - already exists
# Skipping 272.png - already exists
# Skipping 3996.png - already exists
# Skipping 2024.png - already exists
# Skipping 439.png - already exists
# Skipping 1929.png - already exists
# Skipping 2339.png - already exists
# Skipping 905.png - already exists
# Skipping 175.png - already exists
# Skipping 198.png - already exists
# Skipping 1860.png - already exists
# Skipping 399.png - already exists
# Skipping 246.png - already exists
# Skipping 2220.png - already exists
# Skipping 822.png - already exists
# Skipping 2106.png - already exists
# Skipping 3440.png - already exists
# Skipping 202.png - already exists
# Skipping 4218.png - already exists
# Skipping 924.png - already exists
# Skipping 1832.png - already exists
# Skipping 2541.png - already exists
# Skipping 515.png - already exists
# Skipping 4151.png - already exists
# Skipping 4220.png - already exists
# Skipping 1943.png - already exists
# Skipping 475.png - already exists
# Skipping 2073.png - already exists
# Skipping 2433.png - already exists
# Skipping 1914.png - already exists
# Skipping 2475.png - already exists
# Skipping 1943.png - already exists
# Skipping 2939.png - already exists
# Skipping 667.png - already exists
# Skipping 2009.png - already exists
# Skipping 2053.png - already exists
# Skipping 2407.png - already exists
# Skipping 4142.png - already exists
# Skipping 1353.png - already exists
# Skipping 881.png - already exists
# Skipping 3834.png - already exists
# Skipping 1853.png - already exists
# Skipping 4107.png - already exists
# Skipping 758.png - already exists
# Skipping 3212.png - already exists
# Skipping 4201.png - already exists
# Skipping 768.png - already exists
# Skipping 918.png - already exists
# Skipping 456.png - already exists
# Skipping 1740.png - already exists
# Skipping 2511.png - already exists
# Skipping 266.png - already exists
# Skipping 1777.png - already exists
# Skipping 1950.png - already exists
# Skipping 2301.png - already exists
# Skipping 26.png - already exists
# Skipping 2897.png - already exists
# Skipping 1344.png - already exists
# Skipping 4516.png - already exists
# Skipping 3141.png - already exists
# Skipping 2747.png - already exists
# Skipping 4606.png - already exists
# Skipping 3776.png - already exists
# Skipping 2099.png - already exists
# Skipping 1955.png - already exists
# Skipping 1792.png - already exists
# Skipping 4298.png - already exists
# Skipping 3593.png - already exists
# Skipping 3132.png - already exists
# Skipping 1815.png - already exists
# Skipping 4613.png - already exists
# Skipping 256.png - already exists
# Skipping 2374.png - already exists
# Skipping 1995.png - already exists
# Skipping 26.png - already exists
# Skipping 3768.png - already exists
# Skipping 2319.png - already exists
# Skipping 1453.png - already exists
# Skipping 1889.png - already exists
# Skipping 480.png - already exists
# Successfully copied 12000 images
# Failed to copy 0 images

# %%
# open subset_images directory and count the number of files
import os

subset_images_dir = "subset_images"

# Count the number of files in the directory
num_files = len(os.listdir(subset_images_dir))
print(f"Number of files in {subset_images_dir}: {num_files}")
# Out:
# Number of files in subset_images: 3230

# %%
import os
import json
import shutil

# Copy images to subset_images directory
subset_output_file = "ai2d_open_ans_12K_v1_subset.jsonl"
# Create final JSONL with absolute image paths
final_output_file = "ai2d_run1_open_ans_12K_v1_subset.jsonl"
base_dir = "/data/users/brandon/ob1-projects/InternVL/internvl_chat/rollout_generation/preprocessed_prompts/preprocessing_scripts/AI2D"
absolute_subset_images_dir = os.path.join(base_dir, "subset_images")

print(f"Creating final JSONL with absolute image paths: {final_output_file}")

with open(subset_output_file, 'r') as input_f, open(final_output_file, 'w') as output_f:
    for line in input_f:
        record = json.loads(line.strip())
        
        # Extract original filename
        image_filename = os.path.basename(record["image"])
        
        # Create absolute path to the copied image
        absolute_image_path = os.path.join(absolute_subset_images_dir, image_filename)
        
        # Add the image_path field
        record["image_path"] = absolute_image_path
        
        # Write the updated record
        output_f.write(json.dumps(record) + "\n")

print(f"Created final output file: {final_output_file}")

# Show sample of final output
with open(final_output_file, 'r') as f:
    sample_record = json.loads(f.readline())
    print("Sample final record:")
    print(json.dumps(sample_record, indent=2))
# Out:
# Creating final JSONL with absolute image paths: ai2d_run1_open_ans_12K_v1_subset.jsonl
# Created final output file: ai2d_run1_open_ans_12K_v1_subset.jsonl
# Sample final record:
# {
#   "image": "MMPR-v1.2-prompts/correctness_images/ai2d_train_12k_en_20240410_extracted/images/4561.png",
#   "question": "What object is shown in the diagram above?\nOrange tree\nMint Plant\nNone of the above\nApple Tree\nPlease answer the question based on the options mentioned before.",
#   "answer": "Mint Plant",
#   "uid": "be7ce904-2513-4655-9653-d147db2280c7",
#   "image_path": "/data/users/brandon/ob1-projects/InternVL/internvl_chat/rollout_generation/preprocessed_prompts/preprocessing_scripts/AI2D/subset_images/4561.png"
# }
