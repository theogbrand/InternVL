# %%
import json
import random
import uuid
import os
import shutil
from pathlib import Path
import pandas as pd
from collections import defaultdict

print("Imports completed successfully")
# Out:
# Imports completed successfully

# %%
# Load the full JSONL file
input_file = "full_infographics_20240403_qa_20240407_v2_extracted.jsonl"
data = []

print(f"Loading data from {input_file}...")
with open(input_file, 'r') as f:
    for line in f:
        data.append(json.loads(line.strip()))

print(f"Loaded {len(data)} records")
print("Sample record:", data[0])
# Out:
# Loading data from full_infographics_20240403_qa_20240407_v2_extracted.jsonl...
# Loaded 17682 records
# Sample record: {'image': 'MMPR-v1.2-prompts/correctness_images/infographics_20240403_qa_20240407_v2_extracted/41999.jpeg', 'question': 'How much total runs did Sachin and Kohli make together after 146 one-day internationals?\nAnswer the question using a single word or phrase.', 'answer': '11405'}

# %%
# Group by unique images to ensure no duplicates
unique_images = {}
for record in data:
    image_path = record["image"]
    if image_path not in unique_images:
        unique_images[image_path] = record

print(f"Found {len(unique_images)} unique images")
# Out:
# Found 3976 unique images

# %%
# Group by unique images to ensure no duplicates
unique_questions = {}
for record in data:
    question = record["question"]
    if question not in unique_questions:
        unique_questions[question] = record

print(f"Found {len(unique_questions)} unique questions")
# Out:
# Found 17653 unique questions

# %%
# Sample 15K unique records
sample_size = 9000
unique_records = list(unique_questions.values())

if len(unique_records) < sample_size:
    print(f"Warning: Only {len(unique_records)} unique images available, less than requested {sample_size}")
    sampled_data = unique_records
else:
    # Use random.sample for sampling without replacement
    random.seed(42)  # For reproducibility
    sampled_data = random.sample(unique_records, sample_size)

print(f"Selected {len(sampled_data)} records for subset")
# Out:
# Selected 9000 records for subset

# %%
# Add UUID to each record and save subset
subset_output_file = "infovqa_open_ans_9K_v1_subset.jsonl"

print("Adding UIDs and saving subset...")
with open(subset_output_file, 'w') as f:
    for record in sampled_data:
        # Add UID to the record
        record_with_uid = record.copy()
        record_with_uid["uid"] = str(uuid.uuid4())
        
        # Write to file
        f.write(json.dumps(record_with_uid) + "\n")

print(f"Saved {len(sampled_data)} records to {subset_output_file}")
print("Sample record with UID:", json.loads(open(subset_output_file).readline()))
# Out:
# Adding UIDs and saving subset...
# Saved 9000 records to infovqa_open_ans_9K_v1_subset.jsonl
# Sample record with UID: {'image': 'MMPR-v1.2-prompts/correctness_images/infographics_20240403_qa_20240407_v2_extracted/44117.jpeg', 'question': 'How much revenue was generated by the most impactful playoff game in the 2015 season?\nAnswer the question using a single word or phrase.', 'answer': '$1.9M', 'uid': '5d3cccd9-883b-47b9-bbde-b3cde9762ce7'}

# %%
source_image_dir = "/data/users/brandon/ob1-projects/MMPR-v1.2-prompts"
loaded_image_path = "MMPR-v1.2-prompts/correctness_images/infographics_20240403_qa_20240407_v2_extracted/44117.jpeg"

source_image_path = "/".join(loaded_image_path.split("/")[1::])
full_source_image_path = os.path.join(source_image_dir, source_image_path)

print("full_source_image_path: ", full_source_image_path)
# print("loaded_image_path: ", loaded_image_path)


image_filename = os.path.basename(loaded_image_path)
print("image_filename: ", image_filename)
# Out:
# full_source_image_path:  /data/users/brandon/ob1-projects/MMPR-v1.2-prompts/correctness_images/infographics_20240403_qa_20240407_v2_extracted/44117.jpeg
# image_filename:  44117.jpeg

# %%
import os
import json
import shutil

# Copy images to subset_images directory
subset_output_file = "infovqa_open_ans_9K_v1_subset.jsonl"
subset_images_dir = "subset_images"
os.makedirs(subset_images_dir, exist_ok=True)

print(f"Copying images to {subset_images_dir} directory...")

# Read the subset file to get the image paths
copied_count = 0
failed_count = 0

with open(subset_output_file, 'r') as f:
    for line in f:
        record = json.loads(line.strip())
        source_image_path = "/".join(record["image"].split("/")[1::])

        source_image_dir = "/data/users/brandon/ob1-projects/MMPR-v1.2-prompts"

        full_source_image_path = os.path.join(source_image_dir, source_image_path)

        image_filename = os.path.basename(source_image_path)
        
        dest_image_path = os.path.join(subset_images_dir, image_filename)
        
        # Skip if destination already exists to avoid overwriting
        if os.path.exists(dest_image_path):
            print(f"Skipping {image_filename} - already exists")
            copied_count += 1
            continue
        
        try:
            if os.path.exists(full_source_image_path):
                shutil.copy2(full_source_image_path, dest_image_path)
                copied_count += 1
                if copied_count % 1000 == 0:  # Progress update every 1000 files
                    print(f"Copied {copied_count} images so far...")
            else:
                print(f"Warning: Source image not found: {full_source_image_path}")
                failed_count += 1
        except Exception as e:
            print(f"Error copying {full_source_image_path}: {e}")
            failed_count += 1

print(f"Successfully copied {copied_count} images")
print(f"Failed to copy {failed_count} images")
# Out:
# Copying images to subset_images directory...
# Skipping 35859.jpeg - already exists
# Skipping 30543.jpeg - already exists
# Skipping 32918.jpeg - already exists
# Skipping 35570.jpeg - already exists
# Skipping 42468.jpeg - already exists
# Skipping 39118.jpeg - already exists
# Skipping 31661.jpeg - already exists
# Skipping 40513.jpeg - already exists
# Skipping 34432.jpeg - already exists
# Skipping 10069.jpeg - already exists
# Skipping 34390.jpeg - already exists
# Skipping 38337.jpeg - already exists
# Skipping 31646.jpeg - already exists
# Skipping 31183.jpeg - already exists
# Skipping 10469.jpeg - already exists
# Skipping 11342.jpeg - already exists
# Skipping 31646.jpeg - already exists
# Skipping 35900.jpeg - already exists
# Skipping 33998.jpeg - already exists
# Skipping 11145.jpeg - already exists
# Skipping 10092.jpeg - already exists
# Skipping 35920.jpeg - already exists
# Skipping 33937.jpeg - already exists
# Skipping 30191.jpeg - already exists
# Skipping 33058.jpeg - already exists
# Skipping 30564.jpeg - already exists
# Skipping 45579.jpeg - already exists
# Skipping 41570.jpeg - already exists
# Skipping 38285.jpeg - already exists
# Skipping 38519.jpeg - already exists
# Skipping 10226.jpeg - already exists
# Skipping 33884.jpeg - already exists
# Skipping 40599.jpeg - already exists
# Skipping 34450.jpeg - already exists
# Skipping 43182.jpeg - already exists
# Skipping 20401.jpeg - already exists
# Skipping 30801.jpeg - already exists
# Skipping 31661.jpeg - already exists
# Skipping 31243.jpeg - already exists
# Skipping 40582.jpeg - already exists
# Skipping 41240.jpeg - already exists
# Skipping 38408.jpeg - already exists
# Skipping 38297.jpeg - already exists
# Skipping 42526.jpeg - already exists
# Skipping 37841.jpeg - already exists
# Skipping 34334.jpeg - already exists
# Skipping 70596.jpeg - already exists
# Skipping 10866.jpeg - already exists
# Skipping 35935.jpeg - already exists
# Skipping 42327.jpeg - already exists
# Skipping 30213.jpeg - already exists
# Skipping 40146.jpeg - already exists
# Skipping 30152.jpeg - already exists
# Skipping 10750.jpeg - already exists
# Skipping 10942.jpeg - already exists
# Skipping 30627.jpeg - already exists
# Skipping 42207.jpeg - already exists
# Skipping 39135.jpeg - already exists
# Skipping 30690.jpeg - already exists
# Skipping 34334.jpeg - already exists
# Skipping 10516.jpeg - already exists
# Skipping 70184.jpeg - already exists
# Skipping 30234.jpeg - already exists
# Skipping 31579.jpeg - already exists
# Skipping 10715.jpeg - already exists
# Skipping 41472.jpeg - already exists
# Skipping 43451.jpeg - already exists
# Skipping 42320.jpeg - already exists
# Skipping 36005.jpeg - already exists
# Skipping 44932.jpeg - already exists
# Skipping 11294.jpeg - already exists
# Skipping 45518.jpeg - already exists
# Skipping 10422.jpeg - already exists
# Skipping 30455.jpeg - already exists
# Skipping 31177.jpeg - already exists
# Skipping 40599.jpeg - already exists
# Skipping 37945.jpeg - already exists
# Skipping 40476.jpeg - already exists
# Skipping 30468.jpeg - already exists
# Skipping 43441.jpeg - already exists
# Skipping 45553.jpeg - already exists
# Skipping 31761.jpeg - already exists
# Skipping 32240.jpeg - already exists
# Skipping 39009.jpeg - already exists
# Skipping 11230.jpeg - already exists
# Skipping 32219.jpeg - already exists
# Skipping 43650.jpeg - already exists
# Skipping 30857.jpeg - already exists
# Skipping 30301.jpeg - already exists
# Skipping 10335.jpeg - already exists
# Skipping 35991.jpeg - already exists
# Skipping 38841.jpeg - already exists
# Skipping 30090.jpeg - already exists
# Skipping 70182.jpeg - already exists
# Skipping 44858.jpeg - already exists
# Skipping 32694.jpeg - already exists
# Skipping 38216.jpeg - already exists
# Skipping 30701.jpeg - already exists
# Skipping 31128.jpeg - already exists
# Copied 1000 images so far...
# Skipping 11506.jpeg - already exists
# Skipping 38118.jpeg - already exists
# Skipping 31318.jpeg - already exists
# Skipping 30086.jpeg - already exists
# Skipping 42062.jpeg - already exists
# Skipping 42205.jpeg - already exists
# Skipping 40133.jpeg - already exists
# Skipping 38996.jpeg - already exists
# Skipping 30011.jpeg - already exists
# Skipping 38457.jpeg - already exists
# Skipping 31773.jpeg - already exists
# Skipping 41994.jpeg - already exists
# Skipping 31825.jpeg - already exists
# Skipping 38239.jpeg - already exists
# Skipping 10748.jpeg - already exists
# Skipping 31389.jpeg - already exists
# Skipping 32694.jpeg - already exists
# Skipping 33998.jpeg - already exists
# Skipping 10696.jpeg - already exists
# Skipping 43244.jpeg - already exists
# Skipping 30183.jpeg - already exists
# Skipping 10252.jpeg - already exists
# Skipping 70245.jpeg - already exists
# Skipping 70330.jpeg - already exists
# Skipping 39943.jpeg - already exists
# Skipping 30571.jpeg - already exists
# Skipping 70476.jpeg - already exists
# Skipping 30356.jpeg - already exists
# Skipping 34268.jpeg - already exists
# Skipping 10492.jpeg - already exists
# Skipping 31803.jpeg - already exists
# Skipping 43917.jpeg - already exists
# Skipping 35640.jpeg - already exists
# Skipping 43234.jpeg - already exists
# Skipping 32199.jpeg - already exists
# Skipping 30187.jpeg - already exists
# Skipping 37837.jpeg - already exists
# Skipping 11212.jpeg - already exists
# Skipping 35591.jpeg - already exists
# Skipping 31805.jpeg - already exists
# Skipping 10820.jpeg - already exists
# Skipping 38585.jpeg - already exists
# Skipping 40290.jpeg - already exists
# Skipping 35737.jpeg - already exists
# Skipping 38430.jpeg - already exists
# Skipping 10433.jpeg - already exists
# Skipping 31637.jpeg - already exists
# Skipping 30337.jpeg - already exists
# Skipping 11506.jpeg - already exists
# Skipping 38264.jpeg - already exists
# Skipping 40303.jpeg - already exists
# Skipping 38491.jpeg - already exists
# Skipping 45071.jpeg - already exists
# Skipping 33302.jpeg - already exists
# Skipping 38564.jpeg - already exists
# Skipping 10383.jpeg - already exists
# Skipping 11285.jpeg - already exists
# Skipping 20396.jpeg - already exists
# Skipping 10252.jpeg - already exists
# Skipping 37864.jpeg - already exists
# Skipping 30571.jpeg - already exists
# Skipping 43650.jpeg - already exists
# Skipping 30042.jpeg - already exists
# Skipping 31989.jpeg - already exists
# Skipping 41854.jpeg - already exists
# Skipping 40210.jpeg - already exists
# Skipping 44969.jpeg - already exists
# Skipping 30968.jpeg - already exists
# Skipping 31625.jpeg - already exists
# Skipping 39252.jpeg - already exists
# Skipping 11314.jpeg - already exists
# Skipping 31791.jpeg - already exists
# Skipping 35428.jpeg - already exists
# Skipping 33937.jpeg - already exists
# Skipping 34153.jpeg - already exists
# Skipping 38216.jpeg - already exists
# Skipping 35767.jpeg - already exists
# Skipping 11490.jpeg - already exists
# Skipping 41740.jpeg - already exists
# Skipping 40672.jpeg - already exists
# Skipping 30986.jpeg - already exists
# Skipping 44134.jpeg - already exists
# Skipping 10430.jpeg - already exists
# Skipping 41732.jpeg - already exists
# Skipping 40510.jpeg - already exists
# Skipping 40576.jpeg - already exists
# Skipping 40661.jpeg - already exists
# Skipping 38934.jpeg - already exists
# Skipping 31698.jpeg - already exists
# Skipping 32942.jpeg - already exists
# Skipping 30979.jpeg - already exists
# Skipping 32504.jpeg - already exists
# Skipping 42239.jpeg - already exists
# Skipping 41572.jpeg - already exists
# Skipping 10748.jpeg - already exists
# Skipping 70404.jpeg - already exists
# Skipping 35948.jpeg - already exists
# Skipping 34415.jpeg - already exists
# Skipping 70217.jpeg - already exists
# Skipping 38016.jpeg - already exists
# Skipping 35344.jpeg - already exists
# Skipping 10392.jpeg - already exists
# Skipping 35633.jpeg - already exists
# Skipping 35427.jpeg - already exists
# Skipping 38918.jpeg - already exists
# Skipping 33987.jpeg - already exists
# Skipping 31154.jpeg - already exists
# Skipping 31864.jpeg - already exists
# Skipping 41944.jpeg - already exists
# Skipping 10150.jpeg - already exists
# Skipping 31399.jpeg - already exists
# Skipping 32995.jpeg - already exists
# Skipping 35653.jpeg - already exists
# Skipping 10867.jpeg - already exists
# Skipping 43536.jpeg - already exists
# Skipping 37977.jpeg - already exists
# Skipping 10675.jpeg - already exists
# Skipping 70160.jpeg - already exists
# Skipping 30321.jpeg - already exists
# Skipping 37998.jpeg - already exists
# Skipping 35942.jpeg - already exists
# Skipping 31406.jpeg - already exists
# Skipping 31494.jpeg - already exists
# Skipping 37878.jpeg - already exists
# Copied 2000 images so far...
# Skipping 41420.jpeg - already exists
# Skipping 38453.jpeg - already exists
# Skipping 20442.jpeg - already exists
# Skipping 30918.jpeg - already exists
# Skipping 10605.jpeg - already exists
# Skipping 30033.jpeg - already exists
# Skipping 30460.jpeg - already exists
# Skipping 43163.jpeg - already exists
# Skipping 38845.jpeg - already exists
# Skipping 70608.jpeg - already exists
# Skipping 10431.jpeg - already exists
# Skipping 32117.jpeg - already exists
# Skipping 38505.jpeg - already exists
# Skipping 40510.jpeg - already exists
# Skipping 20447.jpeg - already exists
# Skipping 33987.jpeg - already exists
# Skipping 30144.jpeg - already exists
# Skipping 31767.jpeg - already exists
# Skipping 10377.jpeg - already exists
# Skipping 30128.jpeg - already exists
# Skipping 43249.jpeg - already exists
# Skipping 32117.jpeg - already exists
# Skipping 32675.jpeg - already exists
# Skipping 38948.jpeg - already exists
# Skipping 10414.jpeg - already exists
# Skipping 70217.jpeg - already exists
# Skipping 31002.jpeg - already exists
# Skipping 34116.jpeg - already exists
# Skipping 38077.jpeg - already exists
# Skipping 30658.jpeg - already exists
# Skipping 30717.jpeg - already exists
# Skipping 38068.jpeg - already exists
# Skipping 40237.jpeg - already exists
# Skipping 38056.jpeg - already exists
# Skipping 31777.jpeg - already exists
# Skipping 30857.jpeg - already exists
# Skipping 34389.jpeg - already exists
# Skipping 42233.jpeg - already exists
# Skipping 37868.jpeg - already exists
# Skipping 30011.jpeg - already exists
# Skipping 11324.jpeg - already exists
# Skipping 30091.jpeg - already exists
# Skipping 43068.jpeg - already exists
# Skipping 40396.jpeg - already exists
# Skipping 41677.jpeg - already exists
# Skipping 11013.jpeg - already exists
# Skipping 10031.jpeg - already exists
# Skipping 35762.jpeg - already exists
# Skipping 10455.jpeg - already exists
# Skipping 30151.jpeg - already exists
# Skipping 10435.jpeg - already exists
# Skipping 30337.jpeg - already exists
# Skipping 31474.jpeg - already exists
# Skipping 38568.jpeg - already exists
# Skipping 35619.jpeg - already exists
# Skipping 33451.jpeg - already exists
# Skipping 34175.jpeg - already exists
# Skipping 10103.jpeg - already exists
# Skipping 30296.jpeg - already exists
# Skipping 38032.jpeg - already exists
# Skipping 34069.jpeg - already exists
# Skipping 30187.jpeg - already exists
# Skipping 31873.jpeg - already exists
# Skipping 31477.jpeg - already exists
# Skipping 10566.jpeg - already exists
# Skipping 30423.jpeg - already exists
# Skipping 39085.jpeg - already exists
# Skipping 37934.jpeg - already exists
# Skipping 10140.jpeg - already exists
# Skipping 32444.jpeg - already exists
# Skipping 32314.jpeg - already exists
# Skipping 30431.jpeg - already exists
# Skipping 42168.jpeg - already exists
# Skipping 30658.jpeg - already exists
# Skipping 38563.jpeg - already exists
# Skipping 38571.jpeg - already exists
# Skipping 39005.jpeg - already exists
# Skipping 10210.jpeg - already exists
# Skipping 40450.jpeg - already exists
# Skipping 30506.jpeg - already exists
# Skipping 40302.jpeg - already exists
# Skipping 11522.jpeg - already exists
# Skipping 38616.jpeg - already exists
# Skipping 35711.jpeg - already exists
# Skipping 38589.jpeg - already exists
# Skipping 38141.jpeg - already exists
# Skipping 31667.jpeg - already exists
# Skipping 10457.jpeg - already exists
# Skipping 33778.jpeg - already exists
# Skipping 35643.jpeg - already exists
# Skipping 33795.jpeg - already exists
# Skipping 31020.jpeg - already exists
# Skipping 42403.jpeg - already exists
# Skipping 42207.jpeg - already exists
# Skipping 10942.jpeg - already exists
# Skipping 11358.jpeg - already exists
# Skipping 37858.jpeg - already exists
# Skipping 10387.jpeg - already exists
# Skipping 11143.jpeg - already exists
# Skipping 10753.jpeg - already exists
# Skipping 70202.jpeg - already exists
# Skipping 43927.jpeg - already exists
# Skipping 10145.jpeg - already exists
# Skipping 41921.jpeg - already exists
# Skipping 43371.jpeg - already exists
# Skipping 44071.jpeg - already exists
# Skipping 38552.jpeg - already exists
# Skipping 45107.jpeg - already exists
# Skipping 38204.jpeg - already exists
# Skipping 34289.jpeg - already exists
# Skipping 20429.jpeg - already exists
# Skipping 41917.jpeg - already exists
# Skipping 30581.jpeg - already exists
# Skipping 30836.jpeg - already exists
# Skipping 38557.jpeg - already exists
# Skipping 10298.jpeg - already exists
# Skipping 40423.jpeg - already exists
# Skipping 40641.jpeg - already exists
# Skipping 11473.jpeg - already exists
# Skipping 44143.jpeg - already exists
# Skipping 38447.jpeg - already exists
# Skipping 31374.jpeg - already exists
# Skipping 40253.jpeg - already exists
# Skipping 31610.jpeg - already exists
# Skipping 30464.jpeg - already exists
# Skipping 10749.jpeg - already exists
# Skipping 33796.jpeg - already exists
# Skipping 41974.jpeg - already exists
# Skipping 43676.jpeg - already exists
# Skipping 33755.jpeg - already exists
# Skipping 70096.jpeg - already exists
# Skipping 38045.jpeg - already exists
# Skipping 40133.jpeg - already exists
# Skipping 38249.jpeg - already exists
# Skipping 11170.jpeg - already exists
# Skipping 10420.jpeg - already exists
# Skipping 30857.jpeg - already exists
# Skipping 38505.jpeg - already exists
# Skipping 42982.jpeg - already exists
# Skipping 43163.jpeg - already exists
# Skipping 10217.jpeg - already exists
# Skipping 33198.jpeg - already exists
# Skipping 30366.jpeg - already exists
# Skipping 34124.jpeg - already exists
# Skipping 70213.jpeg - already exists
# Skipping 42179.jpeg - already exists
# Skipping 11568.jpeg - already exists
# Skipping 31358.jpeg - already exists
# Skipping 40530.jpeg - already exists
# Skipping 40266.jpeg - already exists
# Skipping 40382.jpeg - already exists
# Skipping 32432.jpeg - already exists
# Skipping 70109.jpeg - already exists
# Skipping 39111.jpeg - already exists
# Skipping 45497.jpeg - already exists
# Skipping 42515.jpeg - already exists
# Skipping 10309.jpeg - already exists
# Skipping 30989.jpeg - already exists
# Skipping 30898.jpeg - already exists
# Skipping 30356.jpeg - already exists
# Skipping 35728.jpeg - already exists
# Skipping 38036.jpeg - already exists
# Skipping 30162.jpeg - already exists
# Skipping 30555.jpeg - already exists
# Skipping 31716.jpeg - already exists
# Skipping 37917.jpeg - already exists
# Skipping 10834.jpeg - already exists
# Skipping 38375.jpeg - already exists
# Skipping 41703.jpeg - already exists
# Skipping 70413.jpeg - already exists
# Skipping 40417.jpeg - already exists
# Skipping 70034.jpeg - already exists
# Skipping 42036.jpeg - already exists
# Skipping 40474.jpeg - already exists
# Skipping 70514.jpeg - already exists
# Skipping 40637.jpeg - already exists
# Skipping 30008.jpeg - already exists
# Skipping 32327.jpeg - already exists
# Skipping 43927.jpeg - already exists
# Skipping 31026.jpeg - already exists
# Skipping 30184.jpeg - already exists
# Skipping 10298.jpeg - already exists
# Skipping 38010.jpeg - already exists
# Skipping 31154.jpeg - already exists
# Skipping 31396.jpeg - already exists
# Skipping 39035.jpeg - already exists
# Skipping 32900.jpeg - already exists
# Skipping 38233.jpeg - already exists
# Skipping 70195.jpeg - already exists
# Skipping 35478.jpeg - already exists
# Skipping 10687.jpeg - already exists
# Skipping 10670.jpeg - already exists
# Skipping 10679.jpeg - already exists
# Skipping 10763.jpeg - already exists
# Skipping 10788.jpeg - already exists
# Skipping 38537.jpeg - already exists
# Skipping 11462.jpeg - already exists
# Skipping 42033.jpeg - already exists
# Skipping 10591.jpeg - already exists
# Skipping 10929.jpeg - already exists
# Skipping 33258.jpeg - already exists
# Skipping 38477.jpeg - already exists
# Skipping 34376.jpeg - already exists
# Skipping 31640.jpeg - already exists
# Skipping 39820.jpeg - already exists
# Skipping 30298.jpeg - already exists
# Skipping 38397.jpeg - already exists
# Skipping 41706.jpeg - already exists
# Skipping 31568.jpeg - already exists
# Skipping 43827.jpeg - already exists
# Skipping 37857.jpeg - already exists
# Skipping 44094.jpeg - already exists
# Skipping 20392.jpeg - already exists
# Skipping 32006.jpeg - already exists
# Skipping 11445.jpeg - already exists
# Skipping 39952.jpeg - already exists
# Skipping 31929.jpeg - already exists
# Skipping 31110.jpeg - already exists
# Skipping 30838.jpeg - already exists
# Skipping 41277.jpeg - already exists
# Skipping 11189.jpeg - already exists
# Skipping 32119.jpeg - already exists
# Skipping 30229.jpeg - already exists
# Skipping 30831.jpeg - already exists
# Skipping 31803.jpeg - already exists
# Skipping 33926.jpeg - already exists
# Skipping 30768.jpeg - already exists
# Skipping 20429.jpeg - already exists
# Skipping 38997.jpeg - already exists
# Skipping 35475.jpeg - already exists
# Skipping 10538.jpeg - already exists
# Skipping 70332.jpeg - already exists
# Skipping 35605.jpeg - already exists
# Skipping 35427.jpeg - already exists
# Skipping 35982.jpeg - already exists
# Skipping 33722.jpeg - already exists
# Skipping 35330.jpeg - already exists
# Skipping 38399.jpeg - already exists
# Skipping 40320.jpeg - already exists
# Skipping 31795.jpeg - already exists
# Skipping 42525.jpeg - already exists
# Skipping 11532.jpeg - already exists
# Skipping 37945.jpeg - already exists
# Skipping 70018.jpeg - already exists
# Skipping 30485.jpeg - already exists
# Skipping 40540.jpeg - already exists
# Skipping 30504.jpeg - already exists
# Skipping 35693.jpeg - already exists
# Skipping 20467.jpeg - already exists
# Skipping 38779.jpeg - already exists
# Skipping 11555.jpeg - already exists
# Skipping 11053.jpeg - already exists
# Skipping 11086.jpeg - already exists
# Skipping 33848.jpeg - already exists
# Skipping 30504.jpeg - already exists
# Skipping 34449.jpeg - already exists
# Skipping 10697.jpeg - already exists
# Skipping 10262.jpeg - already exists
# Skipping 30620.jpeg - already exists
# Skipping 44981.jpeg - already exists
# Skipping 41974.jpeg - already exists
# Skipping 41431.jpeg - already exists
# Skipping 44859.jpeg - already exists
# Skipping 20454.jpeg - already exists
# Skipping 37921.jpeg - already exists
# Skipping 35920.jpeg - already exists
# Skipping 39115.jpeg - already exists
# Skipping 30986.jpeg - already exists
# Skipping 10617.jpeg - already exists
# Skipping 70257.jpeg - already exists
# Skipping 10749.jpeg - already exists
# Skipping 38850.jpeg - already exists
# Skipping 35561.jpeg - already exists
# Skipping 11026.jpeg - already exists
# Skipping 39880.jpeg - already exists
# Skipping 32818.jpeg - already exists
# Skipping 38562.jpeg - already exists
# Skipping 44950.jpeg - already exists
# Skipping 41367.jpeg - already exists
# Skipping 30780.jpeg - already exists
# Skipping 40590.jpeg - already exists
# Skipping 30496.jpeg - already exists
# Skipping 43502.jpeg - already exists
# Skipping 32219.jpeg - already exists
# Skipping 41703.jpeg - already exists
# Skipping 40396.jpeg - already exists
# Skipping 43017.jpeg - already exists
# Skipping 39009.jpeg - already exists
# Skipping 20466.jpeg - already exists
# Skipping 30167.jpeg - already exists
# Skipping 10159.jpeg - already exists
# Skipping 38765.jpeg - already exists
# Skipping 38338.jpeg - already exists
# Skipping 35766.jpeg - already exists
# Skipping 31555.jpeg - already exists
# Skipping 45516.jpeg - already exists
# Skipping 43657.jpeg - already exists
# Skipping 32034.jpeg - already exists
# Skipping 33994.jpeg - already exists
# Skipping 33177.jpeg - already exists
# Skipping 30463.jpeg - already exists
# Skipping 30002.jpeg - already exists
# Skipping 20460.jpeg - already exists
# Skipping 30193.jpeg - already exists
# Skipping 43841.jpeg - already exists
# Skipping 30342.jpeg - already exists
# Skipping 32978.jpeg - already exists
# Skipping 38589.jpeg - already exists
# Skipping 31189.jpeg - already exists
# Skipping 38396.jpeg - already exists
# Skipping 30698.jpeg - already exists
# Skipping 38193.jpeg - already exists
# Skipping 34255.jpeg - already exists
# Skipping 70564.jpeg - already exists
# Skipping 40653.jpeg - already exists
# Skipping 11027.jpeg - already exists
# Skipping 30331.jpeg - already exists
# Skipping 33138.jpeg - already exists
# Skipping 38568.jpeg - already exists
# Skipping 34415.jpeg - already exists
# Skipping 10031.jpeg - already exists
# Skipping 40253.jpeg - already exists
# Skipping 33101.jpeg - already exists
# Skipping 30599.jpeg - already exists
# Skipping 38146.jpeg - already exists
# Skipping 41432.jpeg - already exists
# Skipping 10126.jpeg - already exists
# Skipping 41676.jpeg - already exists
# Skipping 35859.jpeg - already exists
# Skipping 33834.jpeg - already exists
# Skipping 30234.jpeg - already exists
# Skipping 39135.jpeg - already exists
# Skipping 42982.jpeg - already exists
# Skipping 30679.jpeg - already exists
# Skipping 39213.jpeg - already exists
# Skipping 39052.jpeg - already exists
# Skipping 11292.jpeg - already exists
# Skipping 30459.jpeg - already exists
# Skipping 41804.jpeg - already exists
# Skipping 10656.jpeg - already exists
# Skipping 31692.jpeg - already exists
# Skipping 39129.jpeg - already exists
# Skipping 41673.jpeg - already exists
# Skipping 34449.jpeg - already exists
# Skipping 42372.jpeg - already exists
# Skipping 30538.jpeg - already exists
# Skipping 31889.jpeg - already exists
# Skipping 35996.jpeg - already exists
# Skipping 40637.jpeg - already exists
# Skipping 40582.jpeg - already exists
# Skipping 38332.jpeg - already exists
# Skipping 37871.jpeg - already exists
# Skipping 42503.jpeg - already exists
# Skipping 10925.jpeg - already exists
# Skipping 40429.jpeg - already exists
# Skipping 38573.jpeg - already exists
# Skipping 31263.jpeg - already exists
# Skipping 38167.jpeg - already exists
# Skipping 45518.jpeg - already exists
# Skipping 30348.jpeg - already exists
# Skipping 38563.jpeg - already exists
# Skipping 31272.jpeg - already exists
# Skipping 34171.jpeg - already exists
# Skipping 33755.jpeg - already exists
# Skipping 35695.jpeg - already exists
# Skipping 41638.jpeg - already exists
# Skipping 30810.jpeg - already exists
# Skipping 30756.jpeg - already exists
# Skipping 38743.jpeg - already exists
# Skipping 38331.jpeg - already exists
# Skipping 38921.jpeg - already exists
# Skipping 44042.jpeg - already exists
# Skipping 44875.jpeg - already exists
# Skipping 32993.jpeg - already exists
# Skipping 44239.jpeg - already exists
# Skipping 31761.jpeg - already exists
# Skipping 34025.jpeg - already exists
# Skipping 10415.jpeg - already exists
# Skipping 38357.jpeg - already exists
# Skipping 41409.jpeg - already exists
# Skipping 10680.jpeg - already exists
# Skipping 35873.jpeg - already exists
# Skipping 10084.jpeg - already exists
# Skipping 40315.jpeg - already exists
# Skipping 30664.jpeg - already exists
# Skipping 31767.jpeg - already exists
# Skipping 31021.jpeg - already exists
# Skipping 32887.jpeg - already exists
# Skipping 44746.jpeg - already exists
# Skipping 38380.jpeg - already exists
# Skipping 35432.jpeg - already exists
# Skipping 37965.jpeg - already exists
# Skipping 40266.jpeg - already exists
# Skipping 41807.jpeg - already exists
# Skipping 30011.jpeg - already exists
# Skipping 44094.jpeg - already exists
# Skipping 32081.jpeg - already exists
# Skipping 38881.jpeg - already exists
# Skipping 20473.jpeg - already exists
# Skipping 39768.jpeg - already exists
# Skipping 33099.jpeg - already exists
# Skipping 35692.jpeg - already exists
# Skipping 31431.jpeg - already exists
# Skipping 10416.jpeg - already exists
# Skipping 11390.jpeg - already exists
# Skipping 41472.jpeg - already exists
# Skipping 38498.jpeg - already exists
# Skipping 43914.jpeg - already exists
# Skipping 38472.jpeg - already exists
# Skipping 42351.jpeg - already exists
# Skipping 70149.jpeg - already exists
# Skipping 31183.jpeg - already exists
# Skipping 30485.jpeg - already exists
# Skipping 31972.jpeg - already exists
# Skipping 30154.jpeg - already exists
# Skipping 70096.jpeg - already exists
# Skipping 40100.jpeg - already exists
# Skipping 35996.jpeg - already exists
# Skipping 11008.jpeg - already exists
# Skipping 31278.jpeg - already exists
# Skipping 41977.jpeg - already exists
# Skipping 44157.jpeg - already exists
# Skipping 30002.jpeg - already exists
# Skipping 32006.jpeg - already exists
# Skipping 30268.jpeg - already exists
# Skipping 32931.jpeg - already exists
# Skipping 44275.jpeg - already exists
# Skipping 35370.jpeg - already exists
# Skipping 31685.jpeg - already exists
# Skipping 10317.jpeg - already exists
# Skipping 30408.jpeg - already exists
# Skipping 11352.jpeg - already exists
# Skipping 30232.jpeg - already exists
# Skipping 42135.jpeg - already exists
# Skipping 43897.jpeg - already exists
# Skipping 39988.jpeg - already exists
# Skipping 30020.jpeg - already exists
# Skipping 34329.jpeg - already exists
# Skipping 40448.jpeg - already exists
# Skipping 41807.jpeg - already exists
# Skipping 44813.jpeg - already exists
# Skipping 38621.jpeg - already exists
# Skipping 33903.jpeg - already exists
# Skipping 41420.jpeg - already exists
# Skipping 33176.jpeg - already exists
# Skipping 35677.jpeg - already exists
# Skipping 10140.jpeg - already exists
# Skipping 43362.jpeg - already exists
# Skipping 38162.jpeg - already exists
# Skipping 10787.jpeg - already exists
# Skipping 10637.jpeg - already exists
# Skipping 30716.jpeg - already exists
# Skipping 10261.jpeg - already exists
# Skipping 10949.jpeg - already exists
# Skipping 31430.jpeg - already exists
# Skipping 31469.jpeg - already exists
# Skipping 31821.jpeg - already exists
# Skipping 42431.jpeg - already exists
# Skipping 10197.jpeg - already exists
# Skipping 37943.jpeg - already exists
# Skipping 70052.jpeg - already exists
# Skipping 10117.jpeg - already exists
# Skipping 70596.jpeg - already exists
# Skipping 33099.jpeg - already exists
# ...
# Skipping 30948.jpeg - already exists
# Skipping 11372.jpeg - already exists
# Skipping 20457.jpeg - already exists
# Skipping 30543.jpeg - already exists
# Skipping 10572.jpeg - already exists
# Skipping 30608.jpeg - already exists
# Skipping 38095.jpeg - already exists
# Skipping 10937.jpeg - already exists
# Skipping 30425.jpeg - already exists
# Skipping 70604.jpeg - already exists
# Skipping 33142.jpeg - already exists
# Skipping 40497.jpeg - already exists
# Skipping 38919.jpeg - already exists
# Skipping 31126.jpeg - already exists
# Skipping 39158.jpeg - already exists
# Skipping 42351.jpeg - already exists
# Skipping 38865.jpeg - already exists
# Skipping 35996.jpeg - already exists
# Skipping 38993.jpeg - already exists
# Skipping 43747.jpeg - already exists
# Skipping 39017.jpeg - already exists
# Skipping 38270.jpeg - already exists
# Skipping 31513.jpeg - already exists
# Skipping 30562.jpeg - already exists
# Skipping 38902.jpeg - already exists
# Skipping 35970.jpeg - already exists
# Skipping 31482.jpeg - already exists
# Skipping 40672.jpeg - already exists
# Skipping 38313.jpeg - already exists
# Skipping 44992.jpeg - already exists
# Skipping 44348.jpeg - already exists
# Skipping 32575.jpeg - already exists
# Skipping 11282.jpeg - already exists
# Skipping 30051.jpeg - already exists
# Skipping 32482.jpeg - already exists
# Skipping 44969.jpeg - already exists
# Skipping 33911.jpeg - already exists
# Skipping 10656.jpeg - already exists
# Skipping 31177.jpeg - already exists
# Skipping 37891.jpeg - already exists
# Skipping 30782.jpeg - already exists
# Skipping 38398.jpeg - already exists
# Skipping 31283.jpeg - already exists
# Skipping 35541.jpeg - already exists
# Skipping 40675.jpeg - already exists
# Skipping 30319.jpeg - already exists
# Skipping 32488.jpeg - already exists
# Skipping 38278.jpeg - already exists
# Skipping 43650.jpeg - already exists
# Skipping 31972.jpeg - already exists
# Skipping 39002.jpeg - already exists
# Skipping 38968.jpeg - already exists
# Skipping 40559.jpeg - already exists
# Skipping 38022.jpeg - already exists
# Skipping 41902.jpeg - already exists
# Skipping 31284.jpeg - already exists
# Skipping 35854.jpeg - already exists
# Skipping 39196.jpeg - already exists
# Skipping 70070.jpeg - already exists
# Skipping 30574.jpeg - already exists
# Skipping 33176.jpeg - already exists
# Skipping 40555.jpeg - already exists
# Skipping 40128.jpeg - already exists
# Skipping 30847.jpeg - already exists
# Skipping 34407.jpeg - already exists
# Skipping 41464.jpeg - already exists
# Skipping 10247.jpeg - already exists
# Skipping 40096.jpeg - already exists
# Skipping 40411.jpeg - already exists
# Skipping 35774.jpeg - already exists
# Skipping 42297.jpeg - already exists
# Skipping 39032.jpeg - already exists
# Skipping 10175.jpeg - already exists
# Skipping 10064.jpeg - already exists
# Skipping 20455.jpeg - already exists
# Skipping 38051.jpeg - already exists
# Skipping 39137.jpeg - already exists
# Skipping 31115.jpeg - already exists
# Skipping 10683.jpeg - already exists
# Skipping 31129.jpeg - already exists
# Skipping 33052.jpeg - already exists
# Skipping 10090.jpeg - already exists
# Skipping 31305.jpeg - already exists
# Skipping 44317.jpeg - already exists
# Skipping 31177.jpeg - already exists
# Skipping 43005.jpeg - already exists
# Skipping 37894.jpeg - already exists
# Skipping 39194.jpeg - already exists
# Skipping 38478.jpeg - already exists
# Skipping 42377.jpeg - already exists
# Skipping 32616.jpeg - already exists
# Skipping 31705.jpeg - already exists
# Skipping 37920.jpeg - already exists
# Skipping 42297.jpeg - already exists
# Skipping 10542.jpeg - already exists
# Skipping 33669.jpeg - already exists
# Skipping 10112.jpeg - already exists
# Skipping 11153.jpeg - already exists
# Skipping 30319.jpeg - already exists
# Skipping 30160.jpeg - already exists
# Skipping 33966.jpeg - already exists
# Skipping 31738.jpeg - already exists
# Skipping 38840.jpeg - already exists
# Skipping 38523.jpeg - already exists
# Skipping 38902.jpeg - already exists
# Skipping 30816.jpeg - already exists
# Skipping 41471.jpeg - already exists
# Skipping 38107.jpeg - already exists
# Skipping 38324.jpeg - already exists
# Skipping 11078.jpeg - already exists
# Skipping 70471.jpeg - already exists
# Skipping 31125.jpeg - already exists
# Skipping 30918.jpeg - already exists
# Skipping 40315.jpeg - already exists
# Skipping 45504.jpeg - already exists
# Skipping 11208.jpeg - already exists
# Skipping 40617.jpeg - already exists
# Skipping 31474.jpeg - already exists
# Skipping 42137.jpeg - already exists
# Skipping 38127.jpeg - already exists
# Skipping 41220.jpeg - already exists
# Skipping 42528.jpeg - already exists
# Skipping 30721.jpeg - already exists
# Skipping 40398.jpeg - already exists
# Skipping 31632.jpeg - already exists
# Skipping 10179.jpeg - already exists
# Skipping 41944.jpeg - already exists
# Skipping 30632.jpeg - already exists
# Skipping 40582.jpeg - already exists
# Skipping 10447.jpeg - already exists
# Skipping 31964.jpeg - already exists
# Skipping 38840.jpeg - already exists
# Skipping 30688.jpeg - already exists
# Skipping 38560.jpeg - already exists
# Skipping 43712.jpeg - already exists
# Skipping 40220.jpeg - already exists
# Skipping 38125.jpeg - already exists
# Skipping 33950.jpeg - already exists
# Skipping 37916.jpeg - already exists
# Skipping 34347.jpeg - already exists
# Skipping 38929.jpeg - already exists
# Skipping 38086.jpeg - already exists
# Skipping 37969.jpeg - already exists
# Skipping 30799.jpeg - already exists
# Skipping 33094.jpeg - already exists
# Skipping 38813.jpeg - already exists
# Skipping 45521.jpeg - already exists
# Skipping 39049.jpeg - already exists
# Skipping 35828.jpeg - already exists
# Skipping 33577.jpeg - already exists
# Skipping 35462.jpeg - already exists
# Skipping 42128.jpeg - already exists
# Skipping 31723.jpeg - already exists
# Skipping 70094.jpeg - already exists
# Skipping 37963.jpeg - already exists
# Skipping 10558.jpeg - already exists
# Skipping 70197.jpeg - already exists
# Skipping 38619.jpeg - already exists
# Skipping 34054.jpeg - already exists
# Skipping 10005.jpeg - already exists
# Skipping 44118.jpeg - already exists
# Skipping 10722.jpeg - already exists
# Skipping 31279.jpeg - already exists
# Skipping 10309.jpeg - already exists
# Skipping 30850.jpeg - already exists
# Skipping 31487.jpeg - already exists
# Skipping 35633.jpeg - already exists
# Skipping 11227.jpeg - already exists
# Skipping 11203.jpeg - already exists
# Skipping 34381.jpeg - already exists
# Skipping 42179.jpeg - already exists
# Skipping 31978.jpeg - already exists
# Skipping 11245.jpeg - already exists
# Skipping 10103.jpeg - already exists
# Skipping 31077.jpeg - already exists
# Skipping 33764.jpeg - already exists
# Skipping 40670.jpeg - already exists
# Skipping 11501.jpeg - already exists
# Skipping 35549.jpeg - already exists
# Skipping 31834.jpeg - already exists
# Skipping 35975.jpeg - already exists
# Skipping 11203.jpeg - already exists
# Skipping 10429.jpeg - already exists
# Skipping 31840.jpeg - already exists
# Skipping 38550.jpeg - already exists
# Skipping 30452.jpeg - already exists
# Skipping 70400.jpeg - already exists
# Skipping 35724.jpeg - already exists
# Skipping 30551.jpeg - already exists
# Skipping 30278.jpeg - already exists
# Skipping 38052.jpeg - already exists
# Skipping 31810.jpeg - already exists
# Skipping 70309.jpeg - already exists
# Skipping 38000.jpeg - already exists
# Skipping 38541.jpeg - already exists
# Skipping 11490.jpeg - already exists
# Skipping 39016.jpeg - already exists
# Skipping 70560.jpeg - already exists
# Skipping 43242.jpeg - already exists
# Skipping 32984.jpeg - already exists
# Skipping 34360.jpeg - already exists
# Skipping 10871.jpeg - already exists
# Skipping 70567.jpeg - already exists
# Skipping 45511.jpeg - already exists
# Skipping 31541.jpeg - already exists
# Skipping 31810.jpeg - already exists
# Skipping 41566.jpeg - already exists
# Skipping 30448.jpeg - already exists
# Skipping 42377.jpeg - already exists
# Skipping 10943.jpeg - already exists
# Skipping 44206.jpeg - already exists
# Skipping 37984.jpeg - already exists
# Skipping 37995.jpeg - already exists
# Skipping 31221.jpeg - already exists
# Skipping 34268.jpeg - already exists
# Skipping 38177.jpeg - already exists
# Skipping 31431.jpeg - already exists
# Skipping 38151.jpeg - already exists
# Skipping 35976.jpeg - already exists
# Skipping 30161.jpeg - already exists
# Skipping 42273.jpeg - already exists
# Skipping 41767.jpeg - already exists
# Skipping 35429.jpeg - already exists
# Skipping 31234.jpeg - already exists
# Skipping 38079.jpeg - already exists
# Skipping 30385.jpeg - already exists
# Skipping 38370.jpeg - already exists
# Skipping 32429.jpeg - already exists
# Skipping 32886.jpeg - already exists
# Skipping 35870.jpeg - already exists
# Skipping 30090.jpeg - already exists
# Skipping 40417.jpeg - already exists
# Skipping 31528.jpeg - already exists
# Skipping 38236.jpeg - already exists
# Skipping 10474.jpeg - already exists
# Skipping 10706.jpeg - already exists
# Skipping 41776.jpeg - already exists
# Skipping 31260.jpeg - already exists
# Skipping 20460.jpeg - already exists
# Skipping 41367.jpeg - already exists
# Skipping 34168.jpeg - already exists
# Skipping 10020.jpeg - already exists
# Skipping 30254.jpeg - already exists
# Skipping 30226.jpeg - already exists
# Skipping 42273.jpeg - already exists
# Skipping 38959.jpeg - already exists
# Skipping 10336.jpeg - already exists
# Skipping 30944.jpeg - already exists
# Skipping 34171.jpeg - already exists
# Skipping 30608.jpeg - already exists
# Skipping 41778.jpeg - already exists
# Skipping 38944.jpeg - already exists
# Skipping 10191.jpeg - already exists
# Skipping 31525.jpeg - already exists
# Skipping 11386.jpeg - already exists
# Skipping 40372.jpeg - already exists
# Skipping 44992.jpeg - already exists
# Skipping 34450.jpeg - already exists
# Skipping 38361.jpeg - already exists
# Skipping 40243.jpeg - already exists
# Skipping 42487.jpeg - already exists
# Skipping 10017.jpeg - already exists
# Skipping 30987.jpeg - already exists
# Skipping 11018.jpeg - already exists
# Skipping 20418.jpeg - already exists
# Skipping 34183.jpeg - already exists
# Skipping 11340.jpeg - already exists
# Skipping 43132.jpeg - already exists
# Skipping 10290.jpeg - already exists
# Skipping 30397.jpeg - already exists
# Skipping 31640.jpeg - already exists
# Skipping 37850.jpeg - already exists
# Skipping 38196.jpeg - already exists
# Skipping 30096.jpeg - already exists
# Skipping 10535.jpeg - already exists
# Skipping 35333.jpeg - already exists
# Skipping 30776.jpeg - already exists
# Skipping 33873.jpeg - already exists
# Skipping 10525.jpeg - already exists
# Skipping 30705.jpeg - already exists
# Skipping 35384.jpeg - already exists
# Skipping 38070.jpeg - already exists
# Skipping 38768.jpeg - already exists
# Skipping 10664.jpeg - already exists
# Skipping 30479.jpeg - already exists
# Skipping 31690.jpeg - already exists
# Skipping 39252.jpeg - already exists
# Skipping 35846.jpeg - already exists
# Skipping 11348.jpeg - already exists
# Skipping 41265.jpeg - already exists
# Skipping 31418.jpeg - already exists
# Skipping 30843.jpeg - already exists
# Skipping 11488.jpeg - already exists
# Skipping 35618.jpeg - already exists
# Skipping 41886.jpeg - already exists
# Skipping 30367.jpeg - already exists
# Skipping 44071.jpeg - already exists
# Skipping 11494.jpeg - already exists
# Skipping 31332.jpeg - already exists
# Skipping 38382.jpeg - already exists
# Skipping 31608.jpeg - already exists
# Skipping 42467.jpeg - already exists
# Skipping 38215.jpeg - already exists
# Skipping 43152.jpeg - already exists
# Skipping 39191.jpeg - already exists
# Skipping 30222.jpeg - already exists
# Skipping 38796.jpeg - already exists
# Skipping 38191.jpeg - already exists
# Skipping 20405.jpeg - already exists
# Skipping 31430.jpeg - already exists
# Skipping 42298.jpeg - already exists
# Skipping 11208.jpeg - already exists
# Skipping 30530.jpeg - already exists
# Skipping 38212.jpeg - already exists
# Skipping 35333.jpeg - already exists
# Skipping 35854.jpeg - already exists
# Skipping 40570.jpeg - already exists
# Skipping 44039.jpeg - already exists
# Skipping 10020.jpeg - already exists
# Skipping 20438.jpeg - already exists
# Skipping 42541.jpeg - already exists
# Skipping 30664.jpeg - already exists
# Skipping 10085.jpeg - already exists
# Skipping 38931.jpeg - already exists
# Skipping 41698.jpeg - already exists
# Skipping 30163.jpeg - already exists
# Skipping 30705.jpeg - already exists
# Skipping 41220.jpeg - already exists
# Skipping 34311.jpeg - already exists
# Skipping 30216.jpeg - already exists
# Skipping 31751.jpeg - already exists
# Skipping 30462.jpeg - already exists
# Skipping 40578.jpeg - already exists
# Skipping 70160.jpeg - already exists
# Skipping 70372.jpeg - already exists
# Skipping 38043.jpeg - already exists
# Skipping 43215.jpeg - already exists
# Skipping 30708.jpeg - already exists
# Skipping 40122.jpeg - already exists
# Skipping 10638.jpeg - already exists
# Skipping 30506.jpeg - already exists
# Skipping 30031.jpeg - already exists
# Skipping 10561.jpeg - already exists
# Skipping 30785.jpeg - already exists
# Skipping 37939.jpeg - already exists
# Skipping 30750.jpeg - already exists
# Skipping 40607.jpeg - already exists
# Skipping 30175.jpeg - already exists
# Skipping 30420.jpeg - already exists
# Skipping 45519.jpeg - already exists
# Skipping 32993.jpeg - already exists
# Skipping 30538.jpeg - already exists
# Skipping 38886.jpeg - already exists
# Skipping 42545.jpeg - already exists
# Skipping 30320.jpeg - already exists
# Skipping 39191.jpeg - already exists
# Skipping 38169.jpeg - already exists
# Skipping 30209.jpeg - already exists
# Skipping 43159.jpeg - already exists
# Skipping 31268.jpeg - already exists
# Skipping 30062.jpeg - already exists
# Skipping 31646.jpeg - already exists
# Skipping 10832.jpeg - already exists
# Skipping 38363.jpeg - already exists
# Skipping 10223.jpeg - already exists
# Skipping 43225.jpeg - already exists
# Skipping 10494.jpeg - already exists
# Skipping 31505.jpeg - already exists
# Skipping 31761.jpeg - already exists
# Skipping 35388.jpeg - already exists
# Skipping 31387.jpeg - already exists
# Skipping 10338.jpeg - already exists
# Skipping 31449.jpeg - already exists
# Skipping 35653.jpeg - already exists
# Skipping 32655.jpeg - already exists
# Skipping 43771.jpeg - already exists
# Skipping 70245.jpeg - already exists
# Skipping 30174.jpeg - already exists
# Skipping 38930.jpeg - already exists
# Skipping 38885.jpeg - already exists
# Skipping 44797.jpeg - already exists
# Skipping 39030.jpeg - already exists
# Skipping 39049.jpeg - already exists
# Skipping 30706.jpeg - already exists
# Skipping 38187.jpeg - already exists
# Skipping 30495.jpeg - already exists
# Skipping 70594.jpeg - already exists
# Skipping 30719.jpeg - already exists
# Skipping 31582.jpeg - already exists
# Skipping 30067.jpeg - already exists
# Skipping 32580.jpeg - already exists
# Skipping 70365.jpeg - already exists
# Skipping 11502.jpeg - already exists
# Skipping 38945.jpeg - already exists
# Skipping 42128.jpeg - already exists
# Skipping 45513.jpeg - already exists
# Skipping 11344.jpeg - already exists
# Skipping 31148.jpeg - already exists
# Skipping 35672.jpeg - already exists
# Skipping 32935.jpeg - already exists
# Skipping 31395.jpeg - already exists
# Skipping 39853.jpeg - already exists
# Skipping 30877.jpeg - already exists
# Skipping 70338.jpeg - already exists
# Skipping 30031.jpeg - already exists
# Skipping 11382.jpeg - already exists
# Skipping 34450.jpeg - already exists
# Skipping 38057.jpeg - already exists
# Skipping 38899.jpeg - already exists
# Skipping 40237.jpeg - already exists
# Skipping 33140.jpeg - already exists
# Skipping 20396.jpeg - already exists
# Skipping 40450.jpeg - already exists
# Skipping 38930.jpeg - already exists
# Skipping 11541.jpeg - already exists
# Skipping 38267.jpeg - already exists
# Skipping 11359.jpeg - already exists
# Skipping 44348.jpeg - already exists
# Skipping 20453.jpeg - already exists
# Skipping 30815.jpeg - already exists
# Skipping 10084.jpeg - already exists
# Skipping 10540.jpeg - already exists
# Skipping 42292.jpeg - already exists
# Skipping 11414.jpeg - already exists
# Skipping 30951.jpeg - already exists
# Skipping 10255.jpeg - already exists
# Skipping 30405.jpeg - already exists
# Skipping 10447.jpeg - already exists
# Skipping 30824.jpeg - already exists
# Skipping 41742.jpeg - already exists
# Successfully copied 9000 images
# Failed to copy 0 images

# %%
# open subset_images directory and count the number of files
import os

subset_images_dir = "subset_images"

# Count the number of files in the directory
num_files = len(os.listdir(subset_images_dir))
print(f"Number of files in {subset_images_dir}: {num_files}")
# Out:
# Number of files in subset_images: 3434

# %%
import os
import json
import shutil

# Copy images to subset_images directory
subset_output_file = "infovqa_open_ans_9K_v1_subset.jsonl"
# Create final JSONL with absolute image paths
final_output_file = "infovqa_run1_open_ans_9K_v1_subset.jsonl"
base_dir = "/data/users/brandon/ob1-projects/InternVL/internvl_chat/rollout_generation/preprocessed_prompts/preprocessing_scripts/InfoVQA"
absolute_subset_images_dir = os.path.join(base_dir, "subset_images")

print(f"Creating final JSONL with absolute image paths: {final_output_file}")

with open(subset_output_file, 'r') as input_f, open(final_output_file, 'w') as output_f:
    for line in input_f:
        record = json.loads(line.strip())
        
        # Extract original filename
        image_filename = os.path.basename(record["image"])
        
        # Create absolute path to the copied image
        absolute_image_path = os.path.join(absolute_subset_images_dir, image_filename)
        
        # Add the image_path field
        record["image_path"] = absolute_image_path
        
        # Write the updated record
        output_f.write(json.dumps(record) + "\n")

print(f"Created final output file: {final_output_file}")

# Show sample of final output
with open(final_output_file, 'r') as f:
    sample_record = json.loads(f.readline())
    print("Sample final record:")
    print(json.dumps(sample_record, indent=2))
# Out:
# Creating final JSONL with absolute image paths: infovqa_run1_open_ans_9K_v1_subset.jsonl
# Created final output file: infovqa_run1_open_ans_9K_v1_subset.jsonl
# Sample final record:
# {
#   "image": "MMPR-v1.2-prompts/correctness_images/infographics_20240403_qa_20240407_v2_extracted/44117.jpeg",
#   "question": "How much revenue was generated by the most impactful playoff game in the 2015 season?\nAnswer the question using a single word or phrase.",
#   "answer": "$1.9M",
#   "uid": "5d3cccd9-883b-47b9-bbde-b3cde9762ce7",
#   "image_path": "/data/users/brandon/ob1-projects/InternVL/internvl_chat/rollout_generation/preprocessed_prompts/preprocessing_scripts/InfoVQA/subset_images/44117.jpeg"
# }
